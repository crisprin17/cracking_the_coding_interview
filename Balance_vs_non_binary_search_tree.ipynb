# %% [markdown]
# studiare comportamento in seguito a una seguenza random di inserimenti/cancellazioni/ricerche di stringhe
#
# per ogni stringa si decide (con probabilità 0<= p1 <1) se inserirla
#
# prob 0<=p2<1 se cercarla
#
# p3=1-p1-p2 se cancellarla

# %% [markdown]
# # Costriusco albero e funzioni

# %%
import random

# %%
# Generic tree node class 
class TreeNode(object): 
    def __init__(self, val): 
        self.val = val 
        self.left = None
        self.right = None
        self.height = 1

# %%
# AVL tree class which supports the  
# Insert operation 
class AVL_Tree(object): 
  
    # Recursive function to insert key in  
    # subtree rooted with node and returns 
    # new root of subtree. 
    def insert(self, root, key): 
      
        # Step 1 - Perform normal BST 
        if not root: 
            return TreeNode(key) 
        elif key < root.val: 
            root.left = self.insert(root.left, key) 
        else: 
            root.right = self.insert(root.right, key) 
  
        # Step 2 - Update the height of the  
        # ancestor node 
        root.height = 1 + max(self.getHeight(root.left), 
                           self.getHeight(root.right)) 
  
        # Step 3 - Get the balance factor 
        balance = self.getBalance(root) 
  
        # Step 4 - If the node is unbalanced,  
        # then try out the 4 cases 
        # Case 1 - Left Left 
        if balance > 1 and key < root.left.val: 
            return self.rightRotate(root) 
  
        # Case 2 - Right Right 
        if balance < -1 and key > root.right.val: 
            return self.leftRotate(root) 
          # Case 3 - Left Right 
        if balance > 1 and key > root.left.val: 
            root.left = self.leftRotate(root.left) 
            return self.rightRotate(root) 
  
        # Case 4 - Right Left 
        if balance < -1 and key < root.right.val: 
            root.right = self.rightRotate(root.right) 
            return self.leftRotate(root) 
  
        return root 
  
    def leftRotate(self, z): 
  
        y = z.right 
        T2 = y.left 
  
        # Perform rotation 
        y.left = z 
        z.right = T2 
  
        # Update heights 
        z.height = 1 + max(self.getHeight(z.left), 
                         self.getHeight(z.right)) 
        y.height = 1 + max(self.getHeight(y.left), 
                         self.getHeight(y.right)) 
  
        # Return the new root 
        return y 
  
    def rightRotate(self, z): 
  
        y = z.left 
        T3 = y.right 
  
        # Perform rotation 
        y.right = z 
        z.left = T3 
  
        # Update heights 
        z.height = 1 + max(self.getHeight(z.left), 
                        self.getHeight(z.right)) 
        y.height = 1 + max(self.getHeight(y.left), 
                        self.getHeight(y.right)) 
  
        # Return the new root 
        return y 
  
    def getHeight(self, root): 
        if not root: 
            return 0
  
        return root.height 
  
    def getBalance(self, root): 
        if not root: 
            return 0
  
        return self.getHeight(root.left) - self.getHeight(root.right) 
  
    def preOrder(self, root): 
  
        if not root: 
            return
  
        print("{0} ".format(root.val), end="") 
        self.preOrder(root.left) 
        self.preOrder(root.right) 
        
        
    def check_node_binary_search_tree(self, root, key):

        if not root:
            return root

        if (root.val == key):
            return root.val

        if root.left:
            recursive_left = self.check_node_binary_search_tree(root.left, key)
            if recursive_left:
                return True  # node found, no need to look further

        if root.right:
            recursive_right = self.check_node_binary_search_tree(root.right, key)
            if recursive_right:
                return True
   # Recursive function to delete a node with 
    # given key from subtree with given root. 
    # It returns root of the modified subtree. 
    def delete(self, root, key): 
  
        # Step 1 - Perform standard BST delete 
        if not root: 
            return root 
  
        elif key < root.val: 
            root.left = self.delete(root.left, key) 
  
        elif key > root.val: 
            root.right = self.delete(root.right, key) 
  
        else: 
            if root.left is None: 
                temp = root.right 
                root = None
                return temp 
  
            elif root.right is None: 
                temp = root.left 
                root = None
                return temp 
  
            temp = self.getMinValueNode(root.right) 
            root.val = temp.val 
            root.right = self.delete(root.right, 
                                      temp.val) 
  
        # If the tree has only one node, 
        # simply return it 
        if root is None: 
            return root 
  
        # Step 2 - Update the height of the  
        # ancestor node 
        root.height = 1 + max(self.getHeight(root.left), 
                            self.getHeight(root.right)) 
  
        # Step 3 - Get the balance factor 
        balance = self.getBalance(root) 
  
        # Step 4 - If the node is unbalanced,  
        # then try out the 4 cases 
        # Case 1 - Left Left 
        if balance > 1 and self.getBalance(root.left) >= 0: 
            return self.rightRotate(root) 
  
        # Case 2 - Right Right 
        if balance < -1 and self.getBalance(root.right) <= 0: 
            return self.leftRotate(root) 
  
        # Case 3 - Left Right 
        if balance > 1 and self.getBalance(root.left) < 0: 
            root.left = self.leftRotate(root.left) 
            return self.rightRotate(root) 
  
        # Case 4 - Right Left 
        if balance < -1 and self.getBalance(root.right) > 0: 
            root.right = self.rightRotate(root.right) 
            return self.leftRotate(root) 
  
        return root 
  
    def getMinValueNode(self, root): 
        if root is None or root.left is None: 
            return root 
  
        return self.getMinValueNode(root.left)

# %%
import re

import unidecode

file_name = open("capitolo1_ps.txt")
file_name_read = file_name.read()
words = file_name_read.split()

prima_parola = words[0]

# %%
# Driver program to test above function 
myTree = AVL_Tree() 
root = None
  
root = myTree.insert(root, prima_parola)

# %%
import time

inizio = time.time()

for word in words[1:]:
    print('Parola:', word)
    random_probability = random.randrange(0, 300, 1) / 100

    if random_probability < 1:
        myTree.delete(root, word)
        print("cancella")
    elif (random_probability >= 1) and (random_probability < 2):
        myTree.insert(root, word) 
        print("inserisci")
    else:
        myTree.check_node_binary_search_tree(root, word)
        print("cerca")
fine = time.time()
print("tempototale = ", fine - inizio, "secondi")

myTree.preOrder(root)
# Out:
# Parola: I
# cancella
# Parola: Quel
# cancella
# Parola: ramo
# cancella
# Parola: del
# cerca
# Parola: lago
# cancella
# Parola: di
# cerca
# Parola: Como,
# inserisci
# Parola: che
# cerca
# Parola: volge
# inserisci
# Parola: a
# inserisci
# Parola: mezzogiorno,
# cancella
# Parola: tra
# cerca
# Parola: due
# inserisci
# Parola: catene
# cerca
# Parola: non
# inserisci
# Parola: interrotte
# cerca
# Parola: di
# cerca
# Parola: monti,
# cerca
# Parola: tutto
# inserisci
# Parola: a
# cancella
# Parola: seni
# cerca
# Parola: e
# cerca
# Parola: a
# cancella
# Parola: golfi,
# cancella
# Parola: a
# cerca
# Parola: seconda
# cancella
# Parola: dello
# cerca
# Parola: sporgere
# cerca
# Parola: e
# cerca
# Parola: del
# cerca
# Parola: rientrare
# inserisci
# Parola: di
# cerca
# Parola: quelli,
# cancella
# Parola: vien,
# cancella
# Parola: quasi
# cancella
# Parola: a
# inserisci
# Parola: un
# cerca
# Parola: tratto,
# inserisci
# Parola: a
# inserisci
# Parola: ristringersi,
# cancella
# Parola: e
# cancella
# Parola: a
# cerca
# Parola: prender
# cancella
# Parola: corso
# cerca
# Parola: e
# cancella
# Parola: figura
# cancella
# Parola: di
# cerca
# Parola: fiume,
# cerca
# Parola: tra
# inserisci
# Parola: un
# cerca
# Parola: promontorio
# cerca
# Parola: a
# cancella
# Parola: destra,
# inserisci
# Parola: e
# inserisci
# Parola: un'ampia
# inserisci
# Parola: costiera
# inserisci
# Parola: dall'altra
# cancella
# Parola: parte;
# inserisci
# Parola: e
# inserisci
# Parola: il
# inserisci
# Parola: ponte,
# cancella
# Parola: che
# cancella
# Parola: ivi
# cerca
# Parola: congiunge
# cerca
# Parola: le
# inserisci
# Parola: due
# cancella
# Parola: rive,
# inserisci
# Parola: par
# cerca
# Parola: che
# cerca
# Parola: renda
# inserisci
# Parola: ancor
# cancella
# Parola: pi?
# inserisci
# Parola: sensibile
# cancella
# Parola: all'occhio
# inserisci
# Parola: questa
# cerca
# Parola: trasformazione,
# cancella
# Parola: e
# inserisci
# Parola: segni
# cancella
# Parola: il
# cancella
# Parola: punto
# cerca
# Parola: in
# inserisci
# Parola: cui
# inserisci
# Parola: il
# cerca
# Parola: lago
# cancella
# Parola: cessa,
# inserisci
# Parola: e
# cancella
# Parola: l'Adda
# inserisci
# Parola: rincomincia,
# cerca
# Parola: per
# cancella
# Parola: ripigliar
# cancella
# Parola: poi
# cerca
# Parola: nome
# cerca
# Parola: di
# cancella
# Parola: lago
# cerca
# Parola: dove
# cancella
# Parola: le
# inserisci
# Parola: rive,
# cerca
# Parola: allontanandosi
# inserisci
# Parola: di
# cerca
# Parola: nuovo,
# cancella
# Parola: lascian
# inserisci
# Parola: l'acqua
# cancella
# Parola: distendersi
# cerca
# Parola: e
# inserisci
# Parola: rallentarsi
# inserisci
# Parola: in
# cerca
# Parola: nuovi
# inserisci
# Parola: golfi
# cerca
# Parola: e
# cancella
# Parola: in
# inserisci
# Parola: nuovi
# cerca
# Parola: seni.
# cancella
# Parola: La
# inserisci
# Parola: costiera,
# inserisci
# Parola: formata
# cerca
# Parola: dal
# inserisci
# Parola: deposito
# inserisci
# Parola: di
# cerca
# Parola: tre
# inserisci
# Parola: grossi
# cerca
# Parola: torrenti,
# cerca
# Parola: scende
# inserisci
# Parola: appoggiata
# inserisci
# Parola: a
# inserisci
# Parola: due
# inserisci
# Parola: monti
# cerca
# Parola: contigui,
# inserisci
# Parola: l'uno
# cerca
# Parola: detto
# cancella
# Parola: di
# cerca
# Parola: san
# cancella
# Parola: Martino,
# inserisci
# Parola: l'altro,
# inserisci
# Parola: con
# inserisci
# Parola: voce
# cancella
# Parola: lombarda,
# cancella
# Parola: il
# cancella
# Parola: Resegone,
# cerca
# Parola: dai
# cerca
# Parola: molti
# cerca
# Parola: suoi
# inserisci
# Parola: cocuzzoli
# cerca
# Parola: in
# cerca
# Parola: fila,
# cerca
# Parola: che
# inserisci
# Parola: in
# inserisci
# Parola: vero
# cerca
# Parola: lo
# cerca
# Parola: fanno
# cancella
# Parola: somigliare
# cerca
# Parola: a
# cerca
# Parola: una
# cerca
# Parola: sega:
# cancella
# Parola: talch?
# inserisci
# Parola: non
# cancella
# Parola: ?
# cerca
# Parola: chi,
# inserisci
# Parola: al
# cerca
# Parola: primo
# inserisci
# Parola: vederlo,
# cancella
# Parola: purch?
# cancella
# Parola: sia
# cerca
# Parola: di
# inserisci
# Parola: fronte,
# cerca
# Parola: come
# cerca
# Parola: per
# inserisci
# Parola: esempio
# inserisci
# Parola: di
# cerca
# Parola: su
# inserisci
# Parola: le
# cerca
# Parola: mura
# cancella
# Parola: di
# cancella
# Parola: Milano
# cerca
# Parola: che
# inserisci
# Parola: guardano
# inserisci
# Parola: a
# cancella
# Parola: settentrione,
# cancella
# Parola: non
# cancella
# Parola: lo
# inserisci
# Parola: discerna
# inserisci
# Parola: tosto,
# cancella
# Parola: a
# cerca
# Parola: un
# cerca
# Parola: tal
# inserisci
# Parola: contrassegno,
# cancella
# Parola: in
# inserisci
# Parola: quella
# inserisci
# Parola: lunga
# inserisci
# Parola: e
# inserisci
# Parola: vasta
# cerca
# Parola: giogaia,
# inserisci
# Parola: dagli
# inserisci
# Parola: altri
# inserisci
# Parola: monti
# cerca
# Parola: di
# cancella
# Parola: nome
# cerca
# Parola: pi?
# inserisci
# Parola: oscuro
# inserisci
# Parola: e
# inserisci
# Parola: di
# cancella
# Parola: forma
# cerca
# Parola: pi?
# inserisci
# Parola: comune.
# cancella
# Parola: Per
# cancella
# Parola: un
# cancella
# Parola: buon
# cancella
# Parola: pezzo,
# cerca
# Parola: la
# cerca
# Parola: costa
# inserisci
# Parola: sale
# cancella
# Parola: con
# cancella
# Parola: un
# cerca
# Parola: pend?o
# cerca
# Parola: lento
# cerca
# Parola: e
# inserisci
# Parola: continuo;
# cancella
# Parola: poi
# cancella
# Parola: si
# cancella
# Parola: rompe
# cancella
# Parola: in
# inserisci
# Parola: poggi
# inserisci
# Parola: e
# cancella
# Parola: in
# cancella
# Parola: valloncelli,
# cerca
# Parola: in
# cancella
# Parola: erte
# cerca
# Parola: e
# cerca
# Parola: in
# cancella
# Parola: ispianate,
# inserisci
# Parola: secondo
# cerca
# Parola: l'ossatura
# cerca
# Parola: de'
# inserisci
# Parola: due
# inserisci
# Parola: monti,
# cerca
# Parola: e
# cerca
# Parola: il
# cancella
# Parola: lavoro
# cancella
# Parola: dell'acque.
# inserisci
# Parola: Il
# cancella
# Parola: lembo
# cerca
# Parola: estremo,
# cancella
# Parola: tagliato
# cancella
# Parola: dalle
# inserisci
# Parola: foci
# cancella
# Parola: de'
# cerca
# Parola: torrenti,
# inserisci
# Parola: ?
# cerca
# Parola: quasi
# inserisci
# Parola: tutto
# inserisci
# Parola: ghiaia
# inserisci
# Parola: e
# cancella
# Parola: ciottoloni;
# inserisci
# Parola: il
# cerca
# Parola: resto,
# cerca
# Parola: campi
# inserisci
# Parola: e
# inserisci
# Parola: vigne,
# cerca
# Parola: sparse
# cancella
# Parola: di
# cerca
# Parola: terre,
# cancella
# Parola: di
# cerca
# Parola: ville,
# inserisci
# Parola: di
# cancella
# Parola: casali;
# cerca
# Parola: in
# cancella
# Parola: qualche
# cerca
# Parola: parte
# cerca
# Parola: boschi,
# cerca
# Parola: che
# inserisci
# Parola: si
# cerca
# Parola: prolungano
# cancella
# Parola: su
# cerca
# Parola: per
# cerca
# Parola: la
# cancella
# Parola: montagna.
# cancella
# Parola: Lecco,
# cerca
# Parola: la
# inserisci
# Parola: principale
# cerca
# Parola: di
# cancella
# Parola: quelle
# cancella
# Parola: terre,
# cancella
# Parola: e
# cerca
# Parola: che
# cerca
# Parola: d?
# cancella
# Parola: nome
# inserisci
# Parola: al
# cerca
# Parola: territorio,
# inserisci
# Parola: giace
# inserisci
# Parola: poco
# cancella
# Parola: discosto
# inserisci
# Parola: dal
# cancella
# Parola: ponte,
# inserisci
# Parola: alla
# cancella
# Parola: riva
# cancella
# Parola: del
# inserisci
# Parola: lago,
# cerca
# Parola: anzi
# cancella
# Parola: viene
# inserisci
# Parola: in
# cancella
# Parola: parte
# cancella
# Parola: a
# cerca
# Parola: trovarsi
# inserisci
# Parola: nel
# inserisci
# Parola: lago
# cerca
# Parola: stesso,
# inserisci
# Parola: quando
# cerca
# Parola: questo
# inserisci
# Parola: ingrossa:
# cancella
# Parola: un
# cerca
# Parola: gran
# cerca
# Parola: borgo
# inserisci
# Parola: al
# inserisci
# Parola: giorno
# inserisci
# Parola: d'oggi,
# inserisci
# Parola: e
# cancella
# Parola: che
# inserisci
# Parola: s'incammina
# cancella
# Parola: a
# inserisci
# Parola: diventar
# inserisci
# Parola: citt?.
# inserisci
# Parola: Ai
# cerca
# Parola: tempi
# cancella
# Parola: in
# inserisci
# Parola: cui
# cerca
# Parola: accaddero
# cancella
# Parola: i
# cerca
# Parola: fatti
# inserisci
# Parola: che
# cancella
# Parola: prendiamo
# inserisci
# Parola: a
# cerca
# Parola: raccontare,
# inserisci
# Parola: quel
# cancella
# Parola: borgo,
# inserisci
# Parola: gi?
# cancella
# Parola: considerabile,
# inserisci
# Parola: era
# cancella
# Parola: anche
# cerca
# Parola: un
# cancella
# Parola: castello,
# cancella
# Parola: e
# cerca
# Parola: aveva
# cerca
# Parola: perci?
# cerca
# Parola: l'onore
# inserisci
# Parola: d'alloggiare
# inserisci
# Parola: un
# cancella
# Parola: comandante,
# inserisci
# Parola: e
# inserisci
# Parola: il
# inserisci
# Parola: vantaggio
# cancella
# Parola: di
# cancella
# Parola: possedere
# inserisci
# Parola: una
# cancella
# Parola: stabile
# cancella
# Parola: guarnigione
# cerca
# Parola: di
# cancella
# Parola: soldati
# inserisci
# Parola: spagnoli,
# inserisci
# Parola: che
# cancella
# Parola: insegnavan
# inserisci
# Parola: la
# cerca
# Parola: modestia
# cancella
# Parola: alle
# cancella
# Parola: fanciulle
# cancella
# Parola: e
# cerca
# Parola: alle
# cerca
# Parola: donne
# inserisci
# Parola: del
# inserisci
# Parola: paese,
# cancella
# Parola: accarezzavan
# inserisci
# Parola: di
# inserisci
# Parola: tempo
# cancella
# Parola: in
# cerca
# Parola: tempo
# inserisci
# Parola: le
# inserisci
# Parola: spalle
# cancella
# Parola: a
# cerca
# Parola: qualche
# inserisci
# Parola: marito,
# cerca
# Parola: a
# inserisci
# Parola: qualche
# cancella
# Parola: padre;
# cancella
# Parola: e,
# cerca
# Parola: sul
# cancella
# Parola: finir
# cancella
# Parola: dell'estate,
# cerca
# Parola: non
# inserisci
# Parola: mancavan
# inserisci
# Parola: mai
# cerca
# Parola: di
# inserisci
# Parola: spandersi
# inserisci
# Parola: nelle
# inserisci
# Parola: vigne,
# inserisci
# Parola: per
# cancella
# Parola: diradar
# cancella
# Parola: l'uve,
# cancella
# Parola: e
# cerca
# Parola: alleggerire
# cerca
# Parola: a'
# cancella
# Parola: contadini
# cancella
# Parola: le
# cerca
# Parola: fatiche
# inserisci
# Parola: della
# inserisci
# Parola: vendemmia.
# cancella
# Parola: Dall'una
# cancella
# Parola: all'altra
# cerca
# Parola: di
# cancella
# Parola: quelle
# inserisci
# Parola: terre,
# inserisci
# Parola: dall'alture
# inserisci
# Parola: alla
# cerca
# Parola: riva,
# cancella
# Parola: da
# cerca
# Parola: un
# cancella
# Parola: poggio
# inserisci
# Parola: all'altro,
# inserisci
# Parola: correvano,
# inserisci
# Parola: e
# cancella
# Parola: corrono
# cerca
# Parola: tuttavia,
# inserisci
# Parola: strade
# cancella
# Parola: e
# inserisci
# Parola: stradette,
# inserisci
# Parola: pi?
# cancella
# Parola: o
# cancella
# Parola: men
# cancella
# Parola: ripide,
# inserisci
# Parola: o
# cancella
# Parola: piane;
# cancella
# Parola: ogni
# cancella
# Parola: tanto
# cancella
# Parola: affondate,
# cerca
# Parola: sepolte
# cerca
# Parola: tra
# cerca
# Parola: due
# inserisci
# Parola: muri,
# inserisci
# Parola: donde,
# cerca
# Parola: alzando
# inserisci
# Parola: lo
# cerca
# Parola: sguardo,
# cancella
# Parola: non
# inserisci
# Parola: iscoprite
# inserisci
# Parola: che
# cancella
# Parola: un
# inserisci
# Parola: pezzo
# cerca
# Parola: di
# inserisci
# Parola: cielo
# cancella
# Parola: e
# cerca
# Parola: qualche
# inserisci
# Parola: vetta
# inserisci
# Parola: di
# inserisci
# Parola: monte;
# cerca
# Parola: ogni
# cancella
# Parola: tanto
# cancella
# Parola: elevate
# cancella
# Parola: su
# cerca
# Parola: terrapieni
# cancella
# Parola: aperti:
# cerca
# Parola: e
# inserisci
# Parola: da
# cerca
# Parola: qui
# cerca
# Parola: la
# cerca
# Parola: vista
# inserisci
# Parola: spazia
# cancella
# Parola: per
# inserisci
# Parola: prospetti
# inserisci
# Parola: pi?
# inserisci
# Parola: o
# cerca
# Parola: meno
# cerca
# Parola: estesi,
# cancella
# Parola: ma
# inserisci
# Parola: ricchi
# cerca
# Parola: sempre
# inserisci
# Parola: e
# inserisci
# Parola: sempre
# cancella
# Parola: qualcosa
# cancella
# Parola: nuovi,
# inserisci
# Parola: secondo
# inserisci
# Parola: che
# inserisci
# Parola: i
# cancella
# Parola: diversi
# cancella
# Parola: punti
# cancella
# Parola: piglian
# cancella
# Parola: pi?
# cerca
# Parola: o
# inserisci
# Parola: meno
# cancella
# Parola: della
# cerca
# Parola: vasta
# cerca
# Parola: scena
# cerca
# Parola: circostante,
# cancella
# Parola: e
# cerca
# Parola: secondo
# cancella
# Parola: che
# cerca
# Parola: questa
# inserisci
# Parola: o
# cancella
# Parola: quella
# cerca
# Parola: parte
# cerca
# Parola: campeggia
# cerca
# Parola: o
# inserisci
# Parola: si
# inserisci
# Parola: scorcia,
# cancella
# Parola: spunta
# cancella
# Parola: o
# cancella
# Parola: sparisce
# inserisci
# Parola: a
# cerca
# Parola: vicenda.
# cancella
# Parola: Dove
# cancella
# Parola: un
# cancella
# Parola: pezzo,
# cancella
# Parola: dove
# cerca
# Parola: un
# cancella
# Parola: altro,
# inserisci
# Parola: dove
# cancella
# Parola: una
# cerca
# Parola: lunga
# cerca
# Parola: distesa
# inserisci
# Parola: di
# cerca
# Parola: quel
# inserisci
# Parola: vasto
# inserisci
# Parola: e
# inserisci
# Parola: variato
# inserisci
# Parola: specchio
# cancella
# Parola: dell'acqua;
# inserisci
# Parola: di
# inserisci
# Parola: qua
# cancella
# Parola: lago,
# cerca
# Parola: chiuso
# inserisci
# Parola: all'estremit?
# cerca
# Parola: o
# inserisci
# Parola: piuttosto
# inserisci
# Parola: smarrito
# cerca
# Parola: in
# cerca
# Parola: un
# cerca
# Parola: gruppo,
# cerca
# Parola: in
# cerca
# Parola: un
# cancella
# Parola: andirivieni
# inserisci
# Parola: di
# cancella
# Parola: montagne,
# cancella
# Parola: e
# cerca
# Parola: di
# cancella
# Parola: mano
# cerca
# Parola: in
# inserisci
# Parola: mano
# cancella
# Parola: pi?
# cancella
# Parola: allargato
# cerca
# Parola: tra
# cancella
# Parola: altri
# inserisci
# Parola: monti
# cerca
# Parola: che
# inserisci
# Parola: si
# inserisci
# Parola: spiegano,
# inserisci
# Parola: a
# inserisci
# Parola: uno
# cancella
# Parola: a
# inserisci
# Parola: uno,
# cancella
# Parola: allo
# inserisci
# Parola: sguardo,
# inserisci
# Parola: e
# inserisci
# Parola: che
# cerca
# Parola: l'acqua
# cancella
# Parola: riflette
# inserisci
# Parola: capovolti,
# inserisci
# Parola: co'
# inserisci
# Parola: paesetti
# cerca
# Parola: posti
# inserisci
# Parola: sulle
# cancella
# Parola: rive;
# inserisci
# Parola: di
# cerca
# Parola: l?
# cerca
# Parola: braccio
# cerca
# Parola: di
# cancella
# Parola: fiume,
# cancella
# Parola: poi
# cancella
# Parola: lago,
# cancella
# Parola: poi
# cerca
# Parola: fiume
# cancella
# Parola: ancora,
# cerca
# Parola: che
# inserisci
# Parola: va
# inserisci
# Parola: a
# inserisci
# Parola: perdersi
# cancella
# Parola: in
# cancella
# Parola: lucido
# cerca
# Parola: serpeggiamento
# cancella
# Parola: pur
# inserisci
# Parola: tra'
# inserisci
# Parola: monti
# cerca
# Parola: che
# cancella
# Parola: l'accompagnano,
# cerca
# Parola: degradando
# inserisci
# Parola: via
# cancella
# Parola: via,
# inserisci
# Parola: e
# cerca
# Parola: perdendosi
# inserisci
# Parola: quasi
# inserisci
# Parola: anch'essi
# cancella
# Parola: nell'orizzonte.
# cerca
# Parola: Il
# inserisci
# Parola: luogo
# cerca
# Parola: stesso
# cerca
# Parola: da
# cancella
# Parola: dove
# cerca
# Parola: contemplate
# cerca
# Parola: que'
# cancella
# Parola: vari
# cerca
# Parola: spettacoli,
# cerca
# Parola: vi
# inserisci
# Parola: fa
# inserisci
# Parola: spettacolo
# cancella
# Parola: da
# inserisci
# Parola: ogni
# inserisci
# Parola: parte:
# cerca
# Parola: il
# cancella
# Parola: monte
# inserisci
# Parola: di
# inserisci
# Parola: cui
# inserisci
# Parola: passeggiate
# cancella
# Parola: le
# cerca
# Parola: falde,
# cerca
# Parola: vi
# inserisci
# Parola: svolge,
# inserisci
# Parola: al
# cerca
# Parola: di
# cancella
# Parola: sopra,
# inserisci
# Parola: d'intorno,
# cerca
# Parola: le
# cancella
# Parola: sue
# cancella
# Parola: cime
# cancella
# Parola: e
# cerca
# Parola: le
# cancella
# Parola: balze,
# cerca
# Parola: distinte,
# cancella
# Parola: rilevate,
# cancella
# Parola: mutabili
# cancella
# Parola: quasi
# inserisci
# Parola: a
# cerca
# Parola: ogni
# cancella
# Parola: passo,
# inserisci
# Parola: aprendosi
# inserisci
# Parola: e
# cancella
# Parola: contornandosi
# cerca
# Parola: in
# cerca
# Parola: gioghi
# cerca
# Parola: ci?
# cerca
# Parola: che
# cancella
# Parola: v'era
# inserisci
# Parola: sembrato
# inserisci
# Parola: prima
# cancella
# Parola: un
# cancella
# Parola: sol
# cerca
# Parola: giogo,
# cancella
# Parola: e
# cerca
# Parola: comparendo
# inserisci
# Parola: in
# cerca
# Parola: vetta
# inserisci
# Parola: ci?
# cancella
# Parola: che
# cerca
# Parola: poco
# inserisci
# Parola: innanzi
# cancella
# Parola: vi
# cancella
# Parola: si
# cerca
# Parola: rappresentava
# cancella
# Parola: sulla
# cerca
# Parola: costa:
# inserisci
# Parola: e
# cancella
# Parola: l'ameno,
# cerca
# Parola: il
# inserisci
# Parola: domestico
# cancella
# Parola: di
# cancella
# Parola: quelle
# inserisci
# Parola: falde
# inserisci
# Parola: tempera
# inserisci
# Parola: gradevolmente
# cancella
# Parola: il
# cancella
# Parola: selvaggio,
# cancella
# Parola: e
# cerca
# Parola: orna
# inserisci
# Parola: vie
# cancella
# Parola: pi?
# cancella
# Parola: il
# cancella
# Parola: magnifico
# cerca
# Parola: dell'altre
# inserisci
# Parola: vedute.
# cerca
# Parola: Per
# cancella
# Parola: una
# cerca
# Parola: di
# cancella
# Parola: queste
# cerca
# Parola: stradicciole,
# inserisci
# Parola: tornava
# cerca
# Parola: bel
# cancella
# Parola: bello
# cancella
# Parola: dalla
# inserisci
# Parola: passeggiata
# cerca
# Parola: verso
# cancella
# Parola: casa,
# cancella
# Parola: sulla
# inserisci
# Parola: sera
# inserisci
# Parola: del
# cancella
# Parola: giorno
# cancella
# Parola: 7
# cancella
# Parola: novembre
# cancella
# Parola: dell'anno
# inserisci
# Parola: 1628,
# inserisci
# Parola: don
# cancella
# Parola: Abbondio,
# inserisci
# Parola: curato
# inserisci
# Parola: d'una
# cerca
# Parola: delle
# cancella
# Parola: terre
# cancella
# Parola: accennate
# cancella
# Parola: di
# cerca
# Parola: sopra:
# cerca
# Parola: il
# cancella
# Parola: nome
# inserisci
# Parola: di
# inserisci
# Parola: questa,
# inserisci
# Parola: n?
# inserisci
# Parola: il
# cerca
# Parola: casato
# inserisci
# Parola: del
# cerca
# Parola: personaggio,
# inserisci
# Parola: non
# inserisci
# Parola: si
# inserisci
# Parola: trovan
# cerca
# Parola: nel
# inserisci
# Parola: manoscritto,
# cancella
# Parola: n?
# cerca
# Parola: a
# cerca
# Parola: questo
# inserisci
# Parola: luogo
# cerca
# Parola: n?
# cerca
# Parola: altrove.
# cancella
# Parola: Diceva
# cerca
# Parola: tranquillamente
# inserisci
# Parola: il
# cancella
# Parola: suo
# cancella
# Parola: ufizio,
# inserisci
# Parola: e
# cerca
# Parola: talvolta,
# cerca
# Parola: tra
# cerca
# Parola: un
# cancella
# Parola: salmo
# cancella
# Parola: e
# inserisci
# Parola: l'altro,
# cerca
# Parola: chiudeva
# inserisci
# Parola: il
# cancella
# Parola: breviario,
# cancella
# Parola: tenendovi
# inserisci
# Parola: dentro,
# inserisci
# Parola: per
# inserisci
# Parola: segno,
# cerca
# Parola: l'indice
# inserisci
# Parola: della
# cancella
# Parola: mano
# cerca
# Parola: destra,
# cerca
# Parola: e,
# inserisci
# Parola: messa
# cancella
# Parola: poi
# cerca
# Parola: questa
# inserisci
# Parola: nell'altra
# cerca
# Parola: dietro
# cancella
# Parola: la
# cerca
# Parola: schiena,
# cerca
# Parola: proseguiva
# inserisci
# Parola: il
# inserisci
# Parola: suo
# cerca
# Parola: cammino,
# inserisci
# Parola: guardando
# cancella
# Parola: a
# inserisci
# Parola: terra,
# inserisci
# Parola: e
# cancella
# Parola: buttando
# cancella
# Parola: con
# cancella
# Parola: un
# inserisci
# Parola: piede
# cerca
# Parola: verso
# cerca
# Parola: il
# inserisci
# Parola: muro
# cancella
# Parola: i
# cancella
# Parola: ciottoli
# cancella
# Parola: che
# cancella
# Parola: facevano
# cancella
# Parola: inciampo
# cerca
# Parola: nel
# cerca
# Parola: sentiero:
# inserisci
# Parola: poi
# inserisci
# Parola: alzava
# cancella
# Parola: il
# inserisci
# Parola: viso,
# cerca
# Parola: e,
# cancella
# Parola: girati
# cerca
# Parola: oziosamente
# inserisci
# Parola: gli
# cancella
# Parola: occhi
# inserisci
# Parola: all'intorno,
# cancella
# Parola: li
# inserisci
# Parola: fissava
# cerca
# Parola: alla
# inserisci
# Parola: parte
# inserisci
# Parola: d'un
# cerca
# Parola: monte,
# cancella
# Parola: dove
# cancella
# Parola: la
# cancella
# Parola: luce
# cancella
# Parola: del
# cancella
# Parola: sole
# cerca
# Parola: gi?
# cancella
# Parola: scomparso,
# inserisci
# Parola: scappando
# inserisci
# Parola: per
# inserisci
# Parola: i
# inserisci
# Parola: fessi
# inserisci
# Parola: del
# cancella
# Parola: monte
# cancella
# Parola: opposto,
# inserisci
# Parola: si
# cancella
# Parola: dipingeva
# cerca
# Parola: qua
# cerca
# Parola: e
# cerca
# Parola: l?
# inserisci
# Parola: sui
# inserisci
# Parola: massi
# inserisci
# Parola: sporgenti,
# inserisci
# Parola: come
# cancella
# Parola: a
# inserisci
# Parola: larghe
# inserisci
# Parola: e
# cerca
# Parola: inuguali
# inserisci
# Parola: pezze
# cancella
# Parola: di
# cancella
# Parola: porpora.
# cancella
# Parola: Aperto
# inserisci
# Parola: poi
# inserisci
# Parola: di
# cerca
# Parola: nuovo
# inserisci
# Parola: il
# inserisci
# Parola: breviario,
# cancella
# Parola: e
# cancella
# Parola: recitato
# inserisci
# Parola: un
# cancella
# Parola: altro
# inserisci
# Parola: squarcio,
# cancella
# Parola: giunse
# cerca
# Parola: a
# inserisci
# Parola: una
# inserisci
# Parola: voltata
# inserisci
# Parola: della
# cerca
# Parola: stradetta,
# cerca
# Parola: dov'era
# cancella
# Parola: solito
# cerca
# Parola: d'alzar
# inserisci
# Parola: sempre
# cerca
# Parola: gli
# cerca
# Parola: occhi
# cancella
# Parola: dal
# cerca
# Parola: libro,
# cerca
# Parola: e
# inserisci
# Parola: di
# cancella
# Parola: guardarsi
# inserisci
# Parola: dinanzi:
# cancella
# Parola: e
# inserisci
# Parola: cos?
# cancella
# Parola: fece
# inserisci
# Parola: anche
# cerca
# Parola: quel
# inserisci
# Parola: giorno.
# inserisci
# Parola: Dopo
# inserisci
# Parola: la
# inserisci
# Parola: voltata,
# cerca
# Parola: la
# cancella
# Parola: strada
# inserisci
# Parola: correva
# cancella
# Parola: diritta,
# inserisci
# Parola: forse
# cancella
# Parola: un
# cancella
# Parola: sessanta
# cancella
# Parola: passi,
# inserisci
# Parola: e
# cerca
# Parola: poi
# cerca
# Parola: si
# cancella
# Parola: divideva
# cerca
# Parola: in
# cerca
# Parola: due
# cerca
# Parola: viottole,
# inserisci
# Parola: a
# inserisci
# Parola: foggia
# cerca
# Parola: d'un
# cancella
# Parola: ipsilon:
# cerca
# Parola: quella
# cancella
# Parola: a
# cerca
# Parola: destra
# cancella
# Parola: saliva
# inserisci
# Parola: verso
# cancella
# Parola: il
# inserisci
# Parola: monte,
# cancella
# Parola: e
# cancella
# Parola: menava
# inserisci
# Parola: alla
# cancella
# Parola: cura:
# inserisci
# Parola: l'altra
# cerca
# Parola: scendeva
# cancella
# Parola: nella
# cancella
# Parola: valle
# inserisci
# Parola: fino
# inserisci
# Parola: a
# inserisci
# Parola: un
# cancella
# Parola: torrente;
# cerca
# Parola: e
# cerca
# Parola: da
# cancella
# Parola: questa
# cerca
# Parola: parte
# cancella
# Parola: il
# cerca
# Parola: muro
# cancella
# Parola: non
# cancella
# Parola: arrivava
# cerca
# Parola: che
# cerca
# Parola: all'anche
# cerca
# Parola: del
# cancella
# Parola: passeggiero.
# inserisci
# Parola: I
# cancella
# Parola: muri
# cancella
# Parola: interni
# cerca
# Parola: delle
# cerca
# Parola: due
# cancella
# Parola: viottole,
# cerca
# Parola: in
# inserisci
# Parola: vece
# cancella
# Parola: di
# cancella
# Parola: riunirsi
# cancella
# Parola: ad
# inserisci
# Parola: angolo,
# inserisci
# Parola: terminavano
# inserisci
# Parola: in
# cerca
# Parola: un
# inserisci
# Parola: tabernacolo,
# cerca
# Parola: sul
# inserisci
# Parola: quale
# inserisci
# Parola: eran
# inserisci
# Parola: dipinte
# cancella
# Parola: certe
# inserisci
# Parola: figure
# cerca
# Parola: lunghe,
# cancella
# Parola: serpeggianti,
# inserisci
# Parola: che
# inserisci
# Parola: finivano
# cerca
# Parola: in
# inserisci
# Parola: punta,
# inserisci
# Parola: e
# cerca
# Parola: che,
# cerca
# Parola: nell'intenzion
# cerca
# Parola: dell'artista,
# cancella
# Parola: e
# cancella
# Parola: agli
# cancella
# Parola: occhi
# cerca
# Parola: degli
# cerca
# Parola: abitanti
# inserisci
# Parola: del
# inserisci
# Parola: vicinato,
# cancella
# Parola: volevan
# cancella
# Parola: dir
# cancella
# Parola: fiamme;
# cerca
# Parola: e,
# cerca
# Parola: alternate
# inserisci
# Parola: con
# cerca
# Parola: le
# cerca
# Parola: fiamme,
# cancella
# Parola: cert'altre
# cerca
# Parola: figure
# cancella
# Parola: da
# inserisci
# Parola: non
# cancella
# Parola: potersi
# inserisci
# Parola: descrivere,
# cerca
# Parola: che
# inserisci
# Parola: volevan
# cerca
# Parola: dire
# inserisci
# Parola: anime
# cancella
# Parola: del
# cancella
# Parola: purgatorio:
# cancella
# Parola: anime
# cancella
# Parola: e
# cerca
# Parola: fiamme
# cerca
# Parola: a
# cancella
# Parola: color
# cancella
# Parola: di
# cancella
# Parola: mattone,
# inserisci
# Parola: sur
# cerca
# Parola: un
# cancella
# Parola: fondo
# inserisci
# Parola: bigiognolo,
# inserisci
# Parola: con
# cancella
# Parola: qualche
# inserisci
# Parola: scalcinatura
# cancella
# Parola: qua
# cerca
# Parola: e
# inserisci
# Parola: l?.
# cerca
# Parola: Il
# cancella
# Parola: curato,
# inserisci
# Parola: voltata
# cerca
# Parola: la
# cancella
# Parola: stradetta,
# inserisci
# Parola: e
# inserisci
# Parola: dirizzando,
# cerca
# Parola: com'era
# inserisci
# Parola: solito,
# cancella
# Parola: lo
# inserisci
# Parola: sguardo
# cerca
# Parola: al
# cerca
# Parola: tabernacolo,
# inserisci
# Parola: vide
# cancella
# Parola: una
# cancella
# Parola: cosa
# cancella
# Parola: che
# inserisci
# Parola: non
# cerca
# Parola: s'aspettava,
# cerca
# Parola: e
# cancella
# Parola: che
# inserisci
# Parola: non
# cancella
# Parola: avrebbe
# cancella
# Parola: voluto
# cancella
# Parola: vedere.
# cerca
# Parola: Due
# cancella
# Parola: uomini
# inserisci
# Parola: stavano,
# cerca
# Parola: l'uno
# cerca
# Parola: dirimpetto
# cancella
# Parola: all'altro,
# inserisci
# Parola: al
# cerca
# Parola: confluente,
# cerca
# Parola: per
# inserisci
# Parola: dir
# cerca
# Parola: cos?,
# cerca
# Parola: delle
# inserisci
# Parola: due
# cerca
# Parola: viottole:
# cerca
# Parola: un
# inserisci
# Parola: di
# cerca
# Parola: costoro,
# cerca
# Parola: a
# inserisci
# Parola: cavalcioni
# inserisci
# Parola: sul
# cerca
# Parola: muricciolo
# inserisci
# Parola: basso,
# cerca
# Parola: con
# inserisci
# Parola: una
# cancella
# Parola: gamba
# cerca
# Parola: spenzolata
# inserisci
# Parola: al
# cerca
# Parola: di
# cancella
# Parola: fuori,
# cancella
# Parola: e
# cerca
# Parola: l'altro
# cerca
# Parola: piede
# inserisci
# Parola: posato
# inserisci
# Parola: sul
# cancella
# Parola: terreno
# cancella
# Parola: della
# cerca
# Parola: strada;
# cerca
# Parola: il
# cancella
# Parola: compagno,
# inserisci
# Parola: in
# cerca
# Parola: piedi,
# inserisci
# Parola: appoggiato
# inserisci
# Parola: al
# cerca
# Parola: muro,
# cerca
# Parola: con
# cancella
# Parola: le
# cerca
# Parola: braccia
# cerca
# Parola: incrociate
# inserisci
# Parola: sul
# inserisci
# Parola: petto.
# inserisci
# Parola: L'abito,
# cerca
# Parola: il
# inserisci
# Parola: portamento,
# cerca
# Parola: e
# cerca
# Parola: quello
# inserisci
# Parola: che,
# cerca
# Parola: dal
# cancella
# Parola: luogo
# inserisci
# Parola: ov'era
# cerca
# Parola: giunto
# cerca
# Parola: il
# inserisci
# Parola: curato,
# cancella
# Parola: si
# cancella
# Parola: poteva
# cancella
# Parola: distinguer
# cancella
# Parola: dell'aspetto,
# cerca
# Parola: non
# inserisci
# Parola: lasciavan
# cancella
# Parola: dubbio
# cerca
# Parola: intorno
# cancella
# Parola: alla
# inserisci
# Parola: lor
# inserisci
# Parola: condizione.
# cerca
# Parola: Avevano
# inserisci
# Parola: entrambi
# cerca
# Parola: intorno
# inserisci
# Parola: al
# cancella
# Parola: capo
# inserisci
# Parola: una
# inserisci
# Parola: reticella
# inserisci
# Parola: verde,
# cancella
# Parola: che
# cerca
# Parola: cadeva
# cerca
# Parola: sull'omero
# inserisci
# Parola: sinistro,
# inserisci
# Parola: terminata
# cerca
# Parola: in
# cerca
# Parola: una
# inserisci
# Parola: gran
# cerca
# Parola: nappa,
# inserisci
# Parola: e
# inserisci
# Parola: dalla
# cancella
# Parola: quale
# inserisci
# Parola: usciva
# cerca
# Parola: sulla
# cerca
# Parola: fronte
# cerca
# Parola: un
# inserisci
# Parola: enorme
# cancella
# Parola: ciuffo:
# inserisci
# Parola: due
# cancella
# Parola: lunghi
# cancella
# Parola: mustacchi
# cancella
# Parola: arricciati
# cancella
# Parola: in
# cancella
# Parola: punta:
# inserisci
# Parola: una
# cancella
# Parola: cintura
# inserisci
# Parola: lucida
# inserisci
# Parola: di
# inserisci
# Parola: cuoio,
# cerca
# Parola: e
# cerca
# Parola: a
# cerca
# Parola: quella
# cancella
# Parola: attaccate
# cancella
# Parola: due
# cerca
# Parola: pistole:
# cerca
# Parola: un
# cerca
# Parola: piccol
# cancella
# Parola: corno
# cerca
# Parola: ripieno
# inserisci
# Parola: di
# inserisci
# Parola: polvere,
# cancella
# Parola: cascante
# cerca
# Parola: sul
# cerca
# Parola: petto,
# cancella
# Parola: come
# inserisci
# Parola: una
# inserisci
# Parola: collana:
# cerca
# Parola: un
# cerca
# Parola: manico
# cerca
# Parola: di
# cancella
# Parola: coltellaccio
# inserisci
# Parola: che
# cancella
# Parola: spuntava
# cancella
# Parola: fuori
# cerca
# Parola: d'un
# cancella
# Parola: taschino
# cerca
# Parola: degli
# cerca
# Parola: ampi
# inserisci
# Parola: e
# cerca
# Parola: gonfi
# inserisci
# Parola: calzoni:
# inserisci
# Parola: uno
# inserisci
# Parola: spadone,
# inserisci
# Parola: con
# inserisci
# Parola: una
# inserisci
# Parola: gran
# cerca
# Parola: guardia
# inserisci
# Parola: traforata
# cancella
# Parola: a
# cancella
# Parola: lamine
# cancella
# Parola: d'ottone,
# cancella
# Parola: congegnate
# cancella
# Parola: come
# cerca
# Parola: in
# inserisci
# Parola: cifra,
# inserisci
# Parola: forbite
# inserisci
# Parola: e
# cancella
# Parola: lucenti:
# inserisci
# Parola: a
# cancella
# Parola: prima
# cancella
# Parola: vista
# cerca
# Parola: si
# cerca
# Parola: davano
# cancella
# Parola: a
# cerca
# Parola: conoscere
# inserisci
# Parola: per
# inserisci
# Parola: individui
# cancella
# Parola: della
# cancella
# Parola: specie
# cerca
# Parola: de'
# cerca
# Parola: bravi.
# cerca
# Parola: Questa
# cancella
# Parola: specie,
# cancella
# Parola: ora
# cancella
# Parola: del
# inserisci
# Parola: tutto
# cancella
# Parola: perduta,
# cerca
# Parola: era
# cerca
# Parola: allora
# inserisci
# Parola: floridissima
# cerca
# Parola: in
# cancella
# Parola: Lombardia,
# inserisci
# Parola: e
# cancella
# Parola: gi?
# cerca
# Parola: molto
# inserisci
# Parola: antica.
# cancella
# Parola: Chi
# cancella
# Parola: non
# inserisci
# Parola: ne
# cancella
# Parola: avesse
# cancella
# Parola: idea,
# cancella
# Parola: ecco
# cerca
# Parola: alcuni
# cerca
# Parola: squarci
# inserisci
# Parola: autentici,
# inserisci
# Parola: che
# cerca
# Parola: potranno
# cancella
# Parola: darne
# cerca
# Parola: una
# inserisci
# Parola: bastante
# cerca
# Parola: de'
# cerca
# Parola: suoi
# inserisci
# Parola: caratteri
# inserisci
# Parola: principali,
# cancella
# Parola: degli
# inserisci
# Parola: sforzi
# cerca
# Parola: fatti
# cancella
# Parola: per
# cerca
# Parola: ispegnerla,
# inserisci
# Parola: e
# inserisci
# Parola: della
# inserisci
# Parola: sua
# cancella
# Parola: dura
# inserisci
# Parola: e
# cancella
# Parola: rigogliosa
# inserisci
# Parola: vitalit?.
# cancella
# Parola: Fino
# cerca
# Parola: dall'otto
# cancella
# Parola: aprile
# cancella
# Parola: dell'anno
# cerca
# Parola: 1583,
# cancella
# Parola: l'Illustrissimo
# cancella
# Parola: ed
# cancella
# Parola: Eccellentissimo
# cancella
# Parola: signor
# inserisci
# Parola: don
# inserisci
# Parola: Carlo
# inserisci
# Parola: d'Aragon,
# cancella
# Parola: Principe
# cancella
# Parola: di
# cancella
# Parola: Castelvetrano,
# cerca
# Parola: Duca
# cerca
# Parola: di
# inserisci
# Parola: Terranuova,
# cancella
# Parola: Marchese
# cerca
# Parola: d'Avola,
# cancella
# Parola: Conte
# cerca
# Parola: di
# cerca
# Parola: Burgeto,
# cerca
# Parola: grande
# cerca
# Parola: Ammiraglio,
# cancella
# Parola: e
# cancella
# Parola: gran
# cancella
# Parola: Contestabile
# cerca
# Parola: di
# cancella
# Parola: Sicilia,
# cancella
# Parola: Governatore
# inserisci
# Parola: di
# inserisci
# Parola: Milano
# inserisci
# Parola: e
# cerca
# Parola: Capitan
# inserisci
# Parola: Generale
# cerca
# Parola: di
# inserisci
# Parola: Sua
# cerca
# Parola: Maest?
# cancella
# Parola: Cattolica
# cerca
# Parola: in
# inserisci
# Parola: Italia,
# inserisci
# Parola: pienamente
# cerca
# Parola: informato
# cancella
# Parola: della
# inserisci
# Parola: intollerabile
# cancella
# Parola: miseria
# cerca
# Parola: in
# inserisci
# Parola: che
# cancella
# Parola: ?
# cancella
# Parola: vivuta
# inserisci
# Parola: e
# inserisci
# Parola: vive
# cancella
# Parola: questa
# cancella
# Parola: citt?
# cerca
# Parola: di
# cancella
# Parola: Milano,
# inserisci
# Parola: per
# cancella
# Parola: cagione
# cerca
# Parola: dei
# cancella
# Parola: bravi
# cerca
# Parola: e
# cerca
# Parola: vagabondi,
# inserisci
# Parola: pubblica
# cerca
# Parola: un
# cerca
# Parola: bando
# cancella
# Parola: contro
# inserisci
# Parola: di
# cancella
# Parola: essi.
# cerca
# Parola: Dichiara
# cancella
# Parola: e
# cerca
# Parola: diffinisce
# cerca
# Parola: tutti
# cerca
# Parola: coloro
# cancella
# Parola: essere
# inserisci
# Parola: compresi
# cancella
# Parola: in
# inserisci
# Parola: questo
# cancella
# Parola: bando,
# cancella
# Parola: e
# cerca
# Parola: doversi
# cerca
# Parola: ritenere
# inserisci
# Parola: bravi
# inserisci
# Parola: e
# cancella
# Parola: vagabondi...
# cancella
# Parola: i
# cerca
# Parola: quali,
# cerca
# Parola: essendo
# cancella
# Parola: forestieri
# cerca
# Parola: o
# inserisci
# Parola: del
# cancella
# Parola: paese,
# cerca
# Parola: non
# cerca
# Parola: hanno
# cancella
# Parola: esercizio
# cancella
# Parola: alcuno,
# inserisci
# Parola: od
# cancella
# Parola: avendolo,
# cancella
# Parola: non
# cancella
# Parola: lo
# cancella
# Parola: fanno...
# inserisci
# Parola: ma,
# inserisci
# Parola: senza
# inserisci
# Parola: salario,
# cancella
# Parola: o
# cancella
# Parola: pur
# cancella
# Parola: con
# inserisci
# Parola: esso,
# cancella
# Parola: s'appoggiano
# cerca
# Parola: a
# inserisci
# Parola: qualche
# cancella
# Parola: cavaliere
# cancella
# Parola: o
# cancella
# Parola: gentiluomo,
# cerca
# Parola: officiale
# cerca
# Parola: o
# cerca
# Parola: mercante...
# cancella
# Parola: per
# cerca
# Parola: fargli
# inserisci
# Parola: spalle
# cancella
# Parola: e
# cerca
# Parola: favore,
# cerca
# Parola: o
# inserisci
# Parola: veramente,
# inserisci
# Parola: come
# cancella
# Parola: si
# cerca
# Parola: pu?
# inserisci
# Parola: presumere,
# cancella
# Parola: per
# inserisci
# Parola: tendere
# inserisci
# Parola: insidie
# inserisci
# Parola: ad
# cerca
# Parola: altri...
# inserisci
# Parola: A
# inserisci
# Parola: tutti
# cancella
# Parola: costoro
# cancella
# Parola: ordina
# cerca
# Parola: che,
# cerca
# Parola: nel
# cancella
# Parola: termine
# cerca
# Parola: di
# cerca
# Parola: giorni
# cancella
# Parola: sei,
# inserisci
# Parola: abbiano
# cancella
# Parola: a
# inserisci
# Parola: sgomberare
# inserisci
# Parola: il
# inserisci
# Parola: paese,
# cancella
# Parola: intima
# cancella
# Parola: la
# inserisci
# Parola: galera
# cerca
# Parola: a'
# cancella
# Parola: renitenti,
# inserisci
# Parola: e
# inserisci
# Parola: d?
# cerca
# Parola: a
# inserisci
# Parola: tutti
# cancella
# Parola: gli
# cancella
# Parola: ufiziali
# cerca
# Parola: della
# cerca
# Parola: giustizia
# inserisci
# Parola: le
# cerca
# Parola: pi?
# inserisci
# Parola: stranamente
# cancella
# Parola: ampie
# inserisci
# Parola: e
# inserisci
# Parola: indefinite
# inserisci
# Parola: facolt?,
# cancella
# Parola: per
# inserisci
# Parola: l'esecuzione
# cancella
# Parola: dell'ordine.
# cerca
# Parola: Ma,
# cerca
# Parola: nell'anno
# inserisci
# Parola: seguente,
# cerca
# Parola: il
# inserisci
# Parola: 12
# cancella
# Parola: aprile,
# cancella
# Parola: scorgendo
# cerca
# Parola: il
# inserisci
# Parola: detto
# inserisci
# Parola: signore,
# inserisci
# Parola: che
# inserisci
# Parola: questa
# cancella
# Parola: Citt?
# cancella
# Parola: ?
# inserisci
# Parola: tuttavia
# cancella
# Parola: piena
# inserisci
# Parola: di
# cerca
# Parola: detti
# cancella
# Parola: bravi...
# cancella
# Parola: tornati
# cancella
# Parola: a
# cancella
# Parola: vivere
# cerca
# Parola: come
# cerca
# Parola: prima
# cerca
# Parola: vivevano,
# inserisci
# Parola: non
# cancella
# Parola: punto
# cerca
# Parola: mutato
# cerca
# Parola: il
# inserisci
# Parola: costume
# cerca
# Parola: loro,
# cerca
# Parola: n?
# cerca
# Parola: scemato
# cerca
# Parola: il
# inserisci
# Parola: numero,
# inserisci
# Parola: d?
# cerca
# Parola: fuori
# cancella
# Parola: un'altra
# cancella
# Parola: grida,
# cancella
# Parola: ancor
# cancella
# Parola: pi?
# inserisci
# Parola: vigorosa
# cancella
# Parola: e
# cerca
# Parola: notabile,
# cancella
# Parola: nella
# inserisci
# Parola: quale,
# cerca
# Parola: tra
# inserisci
# Parola: l'altre
# inserisci
# Parola: ordinazioni,
# inserisci
# Parola: prescrive:
# cerca
# Parola: Che
# inserisci
# Parola: qualsivoglia
# cerca
# Parola: persona,
# cerca
# Parola: cos?
# inserisci
# Parola: di
# inserisci
# Parola: questa
# inserisci
# Parola: Citt?,
# cancella
# Parola: come
# cerca
# Parola: forestiera,
# cancella
# Parola: che
# inserisci
# Parola: per
# inserisci
# Parola: due
# inserisci
# Parola: testimonj
# cerca
# Parola: conster?
# cerca
# Parola: esser
# inserisci
# Parola: tenuto,
# cancella
# Parola: e
# inserisci
# Parola: comunemente
# inserisci
# Parola: riputato
# inserisci
# Parola: per
# cerca
# Parola: bravo,
# cerca
# Parola: et
# cerca
# Parola: aver
# cancella
# Parola: tal
# inserisci
# Parola: nome,
# cerca
# Parola: ancorch?
# inserisci
# Parola: non
# cancella
# Parola: si
# cerca
# Parola: verifichi
# inserisci
# Parola: aver
# cerca
# Parola: fatto
# cerca
# Parola: delitto
# cancella
# Parola: alcuno...
# cancella
# Parola: per
# cerca
# Parola: questa
# cancella
# Parola: sola
# cerca
# Parola: riputazione
# cerca
# Parola: di
# cancella
# Parola: bravo,
# cancella
# Parola: senza
# cerca
# Parola: altri
# inserisci
# Parola: indizj,
# cancella
# Parola: possa
# cancella
# Parola: dai
# cancella
# Parola: detti
# inserisci
# Parola: giudici
# cerca
# Parola: e
# cerca
# Parola: da
# cancella
# Parola: ognuno
# inserisci
# Parola: di
# cancella
# Parola: loro
# cancella
# Parola: esser
# cancella
# Parola: posto
# inserisci
# Parola: alla
# inserisci
# Parola: corda
# inserisci
# Parola: et
# cerca
# Parola: al
# cerca
# Parola: tormento,
# cerca
# Parola: per
# cerca
# Parola: processo
# cerca
# Parola: informativo...
# cerca
# Parola: et
# inserisci
# Parola: ancorch?
# inserisci
# Parola: non
# cerca
# Parola: confessi
# cancella
# Parola: delitto
# inserisci
# Parola: alcuno,
# cerca
# Parola: tuttavia
# inserisci
# Parola: sia
# inserisci
# Parola: mandato
# cerca
# Parola: alla
# cerca
# Parola: galea,
# inserisci
# Parola: per
# inserisci
# Parola: detto
# inserisci
# Parola: triennio,
# cerca
# Parola: per
# inserisci
# Parola: la
# cancella
# Parola: sola
# cerca
# Parola: opinione
# inserisci
# Parola: e
# cancella
# Parola: nome
# cancella
# Parola: di
# cancella
# Parola: bravo,
# cerca
# Parola: come
# cancella
# Parola: di
# cerca
# Parola: sopra.
# inserisci
# Parola: Tutto
# cerca
# Parola: ci?,
# cerca
# Parola: e
# inserisci
# Parola: il
# cancella
# Parola: di
# cerca
# Parola: pi?
# cancella
# Parola: che
# cancella
# Parola: si
# cancella
# Parola: tralascia,
# cerca
# Parola: perch?
# inserisci
# Parola: Sua
# cerca
# Parola: Eccellenza
# cancella
# Parola: ?
# inserisci
# Parola: risoluta
# cancella
# Parola: di
# cerca
# Parola: voler
# cerca
# Parola: essere
# cancella
# Parola: obbedita
# cancella
# Parola: da
# cancella
# Parola: ognuno.
# cerca
# Parola: All'udir
# cerca
# Parola: parole
# inserisci
# Parola: d'un
# inserisci
# Parola: tanto
# inserisci
# Parola: signore,
# cancella
# Parola: cos?
# cerca
# Parola: gagliarde
# cancella
# Parola: e
# cancella
# Parola: sicure,
# cancella
# Parola: e
# inserisci
# Parola: accompagnate
# cerca
# Parola: da
# cancella
# Parola: tali
# cerca
# Parola: ordini,
# cerca
# Parola: viene
# inserisci
# Parola: una
# cerca
# Parola: gran
# cerca
# Parola: voglia
# cancella
# Parola: di
# inserisci
# Parola: credere
# inserisci
# Parola: che,
# inserisci
# Parola: al
# cerca
# Parola: solo
# cerca
# Parola: rimbombo
# cancella
# Parola: di
# cancella
# Parola: esse,
# inserisci
# Parola: tutti
# cerca
# Parola: i
# cancella
# Parola: bravi
# inserisci
# Parola: siano
# inserisci
# Parola: scomparsi
# inserisci
# Parola: per
# cancella
# Parola: sempre.
# cerca
# Parola: Ma
# inserisci
# Parola: la
# inserisci
# Parola: testimonianza
# cerca
# Parola: d'un
# inserisci
# Parola: signore
# cerca
# Parola: non
# cancella
# Parola: meno
# inserisci
# Parola: autorevole,
# inserisci
# Parola: n?
# cerca
# Parola: meno
# inserisci
# Parola: dotato
# cancella
# Parola: di
# cancella
# Parola: nomi,
# cerca
# Parola: ci
# cancella
# Parola: obbliga
# inserisci
# Parola: a
# cancella
# Parola: credere
# inserisci
# Parola: tutto
# inserisci
# Parola: il
# cerca
# Parola: contrario.
# cerca
# Parola: ?
# cerca
# Parola: questi
# cancella
# Parola: l'Illustrissimo
# inserisci
# Parola: ed
# cancella
# Parola: Eccellentissimo
# inserisci
# Parola: Signor
# cerca
# Parola: Juan
# inserisci
# Parola: Fernandez
# cancella
# Parola: de
# cerca
# Parola: Velasco,
# cancella
# Parola: Contestabile
# cerca
# Parola: di
# inserisci
# Parola: Castiglia,
# cerca
# Parola: Cameriero
# inserisci
# Parola: maggiore
# cerca
# Parola: di
# cancella
# Parola: Sua
# cerca
# Parola: Maest?,
# inserisci
# Parola: Duca
# cancella
# Parola: della
# cerca
# Parola: Citt?
# cerca
# Parola: di
# cancella
# Parola: Frias,
# inserisci
# Parola: Conte
# inserisci
# Parola: di
# cancella
# Parola: Haro
# cerca
# Parola: e
# cancella
# Parola: Castelnovo,
# cancella
# Parola: Signore
# inserisci
# Parola: della
# cerca
# Parola: Casa
# cerca
# Parola: di
# inserisci
# Parola: Velasco,
# cerca
# Parola: e
# inserisci
# Parola: di
# cerca
# Parola: quella
# inserisci
# Parola: delli
# cancella
# Parola: sette
# inserisci
# Parola: Infanti
# inserisci
# Parola: di
# inserisci
# Parola: Lara,
# cancella
# Parola: Governatore
# cerca
# Parola: dello
# cancella
# Parola: Stato
# cancella
# Parola: di
# inserisci
# Parola: Milano,
# cancella
# Parola: etc.
# inserisci
# Parola: Il
# cerca
# Parola: 5
# cancella
# Parola: giugno
# cerca
# Parola: dell'anno
# inserisci
# Parola: 1593,
# cancella
# Parola: pienamente
# cerca
# Parola: informato
# cancella
# Parola: anche
# cancella
# Parola: lui
# cerca
# Parola: di
# cerca
# Parola: quanto
# cerca
# Parola: danno
# cancella
# Parola: e
# inserisci
# Parola: rovine
# cancella
# Parola: sieno...
# inserisci
# Parola: i
# inserisci
# Parola: bravi
# cancella
# Parola: e
# cerca
# Parola: vagabondi,
# cerca
# Parola: e
# cancella
# Parola: del
# inserisci
# Parola: pessimo
# inserisci
# Parola: effetto
# cerca
# Parola: che
# inserisci
# Parola: tal
# inserisci
# Parola: sorta
# cancella
# Parola: di
# inserisci
# Parola: gente,
# cancella
# Parola: fa
# cancella
# Parola: contra
# cerca
# Parola: il
# inserisci
# Parola: ben
# inserisci
# Parola: pubblico,
# cancella
# Parola: et
# cerca
# Parola: in
# inserisci
# Parola: delusione
# inserisci
# Parola: della
# inserisci
# Parola: giustizia,
# cerca
# Parola: intima
# cerca
# Parola: loro
# inserisci
# Parola: di
# inserisci
# Parola: nuovo
# inserisci
# Parola: che,
# inserisci
# Parola: nel
# cerca
# Parola: termine
# cerca
# Parola: di
# cerca
# Parola: giorni
# cerca
# Parola: sei,
# cerca
# Parola: abbiano
# cerca
# Parola: a
# inserisci
# Parola: sbrattare
# cancella
# Parola: il
# cerca
# Parola: paese,
# cancella
# Parola: ripetendo
# inserisci
# Parola: a
# cerca
# Parola: un
# inserisci
# Parola: dipresso
# cerca
# Parola: le
# cancella
# Parola: prescrizioni
# cancella
# Parola: e
# cerca
# Parola: le
# cerca
# Parola: minacce
# cancella
# Parola: medesime
# inserisci
# Parola: del
# inserisci
# Parola: suo
# cerca
# Parola: predecessore.
# inserisci
# Parola: Il
# inserisci
# Parola: 23
# cancella
# Parola: maggio
# inserisci
# Parola: poi
# cancella
# Parola: dell'anno
# cerca
# Parola: 1598,
# cerca
# Parola: informato,
# cancella
# Parola: con
# inserisci
# Parola: non
# inserisci
# Parola: poco
# cerca
# Parola: dispiacere
# inserisci
# Parola: dell'animo
# inserisci
# Parola: suo,
# inserisci
# Parola: che...
# cerca
# Parola: ogni
# cerca
# Parola: d?
# inserisci
# Parola: pi?
# cerca
# Parola: in
# inserisci
# Parola: questa
# cerca
# Parola: Citt?
# inserisci
# Parola: e
# inserisci
# Parola: Stato
# cerca
# Parola: va
# cancella
# Parola: crescendo
# cancella
# Parola: il
# cancella
# Parola: numero
# cancella
# Parola: di
# cerca
# Parola: questi
# cerca
# Parola: tali(bravi
# inserisci
# Parola: e
# inserisci
# Parola: vagabondi),
# cerca
# Parola: n?
# cancella
# Parola: di
# cancella
# Parola: loro,
# cerca
# Parola: giorno
# cancella
# Parola: e
# cerca
# Parola: notte,
# cerca
# Parola: altro
# cerca
# Parola: si
# cerca
# Parola: sente
# cerca
# Parola: che
# cerca
# Parola: ferite
# inserisci
# Parola: appostatamente
# cancella
# Parola: date,
# cerca
# Parola: omicidii
# cancella
# Parola: e
# cerca
# Parola: ruberie
# inserisci
# Parola: et
# cerca
# Parola: ogni
# cerca
# Parola: altra
# cerca
# Parola: qualit?
# cancella
# Parola: di
# inserisci
# Parola: delitti,
# inserisci
# Parola: ai
# cancella
# Parola: quali
# cerca
# Parola: si
# cerca
# Parola: rendono
# cerca
# Parola: pi?
# cancella
# Parola: facili,
# cancella
# Parola: confidati
# cancella
# Parola: essi
# cancella
# Parola: bravi
# cancella
# Parola: d'essere
# inserisci
# Parola: aiutati
# cancella
# Parola: dai
# cerca
# Parola: capi
# cancella
# Parola: e
# cancella
# Parola: fautori
# inserisci
# Parola: loro...
# cancella
# Parola: prescrive
# inserisci
# Parola: di
# cerca
# Parola: nuovo
# inserisci
# Parola: gli
# cerca
# Parola: stessi
# cancella
# Parola: rimedi,
# cancella
# Parola: accrescendo
# cancella
# Parola: la
# cerca
# Parola: dose,
# cerca
# Parola: come
# inserisci
# Parola: s'usa
# inserisci
# Parola: nelle
# inserisci
# Parola: malattie
# cerca
# Parola: ostinate.
# cancella
# Parola: Ognuno
# cerca
# Parola: dunque,
# inserisci
# Parola: conchiude
# cerca
# Parola: poi,
# cerca
# Parola: onninamente
# inserisci
# Parola: si
# inserisci
# Parola: guardi
# inserisci
# Parola: di
# cerca
# Parola: contravvenire
# inserisci
# Parola: in
# cancella
# Parola: parte
# cancella
# Parola: alcuna
# inserisci
# Parola: alla
# inserisci
# Parola: grida
# cancella
# Parola: presente,
# cancella
# Parola: perch?,
# cerca
# Parola: in
# cerca
# Parola: luogo
# cerca
# Parola: di
# cerca
# Parola: provare
# inserisci
# Parola: la
# inserisci
# Parola: clemenza
# inserisci
# Parola: di
# inserisci
# Parola: Sua
# cancella
# Parola: Eccellenza,
# cancella
# Parola: prover?
# cerca
# Parola: il
# inserisci
# Parola: rigore,
# cerca
# Parola: e
# inserisci
# Parola: l'ira
# cerca
# Parola: sua...
# inserisci
# Parola: essendo
# inserisci
# Parola: risoluta
# inserisci
# Parola: e
# cancella
# Parola: determinata
# cerca
# Parola: che
# cerca
# Parola: questa
# inserisci
# Parola: sia
# cancella
# Parola: l'ultima
# inserisci
# Parola: e
# inserisci
# Parola: perentoria
# cancella
# Parola: monizione.
# cerca
# Parola: Non
# cerca
# Parola: fu
# cerca
# Parola: per?
# cerca
# Parola: di
# inserisci
# Parola: questo
# cerca
# Parola: parere
# cerca
# Parola: l'Illustrissimo
# cerca
# Parola: ed
# inserisci
# Parola: Eccellentissimo
# cerca
# Parola: Signore,
# inserisci
# Parola: il
# inserisci
# Parola: Signor
# cancella
# Parola: Don
# inserisci
# Parola: Pietro
# inserisci
# Parola: Enriquez
# cerca
# Parola: de
# cerca
# Parola: Acevedo,
# cerca
# Parola: Conte
# inserisci
# Parola: di
# cancella
# Parola: Fuentes,
# cerca
# Parola: Capitano,
# cancella
# Parola: e
# inserisci
# Parola: Governatore
# inserisci
# Parola: dello
# inserisci
# Parola: Stato
# inserisci
# Parola: di
# inserisci
# Parola: Milano;
# cerca
# Parola: non
# cerca
# Parola: fu
# cancella
# Parola: di
# cerca
# Parola: questo
# inserisci
# Parola: parere,
# cerca
# Parola: e
# cerca
# Parola: per
# inserisci
# Parola: buone
# cerca
# Parola: ragioni.
# cancella
# Parola: Pienamente
# cerca
# Parola: informato
# cerca
# Parola: della
# cancella
# Parola: miseria
# inserisci
# Parola: in
# cerca
# Parola: che
# cerca
# Parola: vive
# cancella
# Parola: questa
# inserisci
# Parola: Citt?
# cerca
# Parola: e
# cancella
# Parola: Stato
# cancella
# Parola: per
# inserisci
# Parola: cagione
# cancella
# Parola: del
# cerca
# Parola: gran
# cerca
# Parola: numero
# cerca
# Parola: di
# cancella
# Parola: bravi
# inserisci
# Parola: che
# cerca
# Parola: in
# cerca
# Parola: esso
# inserisci
# Parola: abbonda...
# cerca
# Parola: e
# cancella
# Parola: risoluto
# inserisci
# Parola: di
# cancella
# Parola: totalmente
# cerca
# Parola: estirpare
# inserisci
# Parola: seme
# cerca
# Parola: tanto
# cancella
# Parola: pernizioso,
# cancella
# Parola: d?
# inserisci
# Parola: fuori,
# cerca
# Parola: il
# cancella
# Parola: 5
# cancella
# Parola: decembre
# inserisci
# Parola: 1600,
# inserisci
# Parola: una
# cancella
# Parola: nuova
# cancella
# Parola: grida
# cerca
# Parola: piena
# cancella
# Parola: anch'essa
# inserisci
# Parola: di
# cerca
# Parola: severissime
# inserisci
# Parola: comminazioni,
# inserisci
# Parola: con
# cerca
# Parola: fermo
# cerca
# Parola: proponimento
# cerca
# Parola: che,
# inserisci
# Parola: con
# cancella
# Parola: ogni
# inserisci
# Parola: rigore,
# cancella
# Parola: e
# inserisci
# Parola: senza
# cancella
# Parola: speranza
# cerca
# Parola: di
# cancella
# Parola: remissione,
# cancella
# Parola: siano
# cancella
# Parola: onninamente
# inserisci
# Parola: eseguite.
# inserisci
# Parola: Convien
# inserisci
# Parola: credere
# cerca
# Parola: per?
# inserisci
# Parola: che
# cerca
# Parola: non
# cerca
# Parola: ci
# inserisci
# Parola: si
# inserisci
# Parola: mettesse
# inserisci
# Parola: con
# cancella
# Parola: tutta
# inserisci
# Parola: quella
# inserisci
# Parola: buona
# cerca
# Parola: voglia
# cerca
# Parola: che
# cerca
# Parola: sapeva
# cancella
# Parola: impiegare
# cerca
# Parola: nell'ordir
# cerca
# Parola: cabale,
# inserisci
# Parola: e
# inserisci
# Parola: nel
# inserisci
# Parola: suscitar
# inserisci
# Parola: nemici
# inserisci
# Parola: al
# cerca
# Parola: suo
# cancella
# Parola: gran
# inserisci
# Parola: nemico
# cancella
# Parola: Enrico
# cancella
# Parola: IV;
# cancella
# Parola: giacch?,
# inserisci
# Parola: per
# inserisci
# Parola: questa
# cerca
# Parola: parte,
# inserisci
# Parola: la
# cancella
# Parola: storia
# inserisci
# Parola: attesta
# inserisci
# Parola: come
# cancella
# Parola: riuscisse
# inserisci
# Parola: ad
# cancella
# Parola: armare
# inserisci
# Parola: contro
# inserisci
# Parola: quel
# cancella
# Parola: re
# cancella
# Parola: il
# inserisci
# Parola: duca
# cerca
# Parola: di
# cancella
# Parola: Savoia,
# cancella
# Parola: a
# inserisci
# Parola: cui
# cancella
# Parola: fece
# cancella
# Parola: perder
# cerca
# Parola: pi?
# cerca
# Parola: d'una
# cancella
# Parola: citt?;
# cancella
# Parola: come
# cerca
# Parola: riuscisse
# cerca
# Parola: a
# cancella
# Parola: far
# cancella
# Parola: congiurare
# cerca
# Parola: il
# cancella
# Parola: duca
# inserisci
# Parola: di
# inserisci
# Parola: Biron,
# cerca
# Parola: a
# cerca
# Parola: cui
# cancella
# Parola: fece
# cerca
# Parola: perder
# cancella
# Parola: la
# cerca
# Parola: testa;
# cancella
# Parola: ma,
# cancella
# Parola: per
# cancella
# Parola: ci?
# inserisci
# Parola: che
# cancella
# Parola: riguarda
# cerca
# Parola: quel
# cancella
# Parola: seme
# cerca
# Parola: tanto
# cancella
# Parola: pernizioso
# cancella
# Parola: de'
# cerca
# Parola: bravi,
# cancella
# Parola: certo
# inserisci
# Parola: ?
# inserisci
# Parola: che
# cancella
# Parola: esso
# cancella
# Parola: continuava
# cancella
# Parola: a
# cerca
# Parola: germogliare,
# inserisci
# Parola: il
# inserisci
# Parola: 22
# inserisci
# Parola: settembre
# cancella
# Parola: dell'anno
# cancella
# Parola: 1612.
# inserisci
# Parola: In
# cerca
# Parola: quel
# cancella
# Parola: giorno
# cerca
# Parola: l'Illustrissimo
# cancella
# Parola: ed
# inserisci
# Parola: Eccellentissimo
# cerca
# Parola: Signore,
# cerca
# Parola: il
# cerca
# Parola: Signor
# cancella
# Parola: Don
# cancella
# Parola: Giovanni
# cancella
# Parola: de
# cancella
# Parola: Mendozza,
# inserisci
# Parola: Marchese
# cancella
# Parola: de
# cerca
# Parola: la
# inserisci
# Parola: Hynojosa,
# cerca
# Parola: Gentiluomo
# cancella
# Parola: etc.,
# inserisci
# Parola: Governatore
# cancella
# Parola: etc.,
# inserisci
# Parola: pens?
# cerca
# Parola: seriamente
# cancella
# Parola: ad
# cerca
# Parola: estirparlo.
# inserisci
# Parola: A
# cancella
# Parola: quest'effetto,
# cancella
# Parola: sped?
# inserisci
# Parola: a
# inserisci
# Parola: Pandolfo
# cerca
# Parola: e
# cerca
# Parola: Marco
# inserisci
# Parola: Tullio
# cancella
# Parola: Malatesti,
# cancella
# Parola: stampatori
# cerca
# Parola: regii
# cerca
# Parola: camerali,
# cancella
# Parola: la
# cancella
# Parola: solita
# cancella
# Parola: grida,
# cerca
# Parola: corretta
# cancella
# Parola: ed
# inserisci
# Parola: accresciuta,
# inserisci
# Parola: perch?
# cerca
# Parola: la
# cancella
# Parola: stampassero
# inserisci
# Parola: ad
# inserisci
# Parola: esterminio
# inserisci
# Parola: de'
# inserisci
# Parola: bravi.
# inserisci
# Parola: Ma
# inserisci
# Parola: questi
# cerca
# Parola: vissero
# cerca
# Parola: ancora
# cerca
# Parola: per
# inserisci
# Parola: ricevere,
# cancella
# Parola: il
# cerca
# Parola: 24
# cerca
# Parola: decembre
# cancella
# Parola: dell'anno
# inserisci
# Parola: 1618,
# inserisci
# Parola: gli
# cerca
# Parola: stessi
# cancella
# Parola: e
# cerca
# Parola: pi?
# cerca
# Parola: forti
# cerca
# Parola: colpi
# inserisci
# Parola: dall'Illustrissimo
# inserisci
# Parola: ed
# inserisci
# Parola: Eccellentissimo
# cerca
# Parola: Signore,
# cerca
# Parola: il
# cerca
# Parola: Signor
# cerca
# Parola: Don
# cerca
# Parola: Gomez
# cancella
# Parola: Suarez
# cerca
# Parola: de
# cancella
# Parola: Figueroa,
# cancella
# Parola: Duca
# cancella
# Parola: di
# inserisci
# Parola: Feria,
# cerca
# Parola: etc.,
# cerca
# Parola: Governatore
# cerca
# Parola: etc.
# cerca
# Parola: Per?,
# cerca
# Parola: non
# cerca
# Parola: essendo
# cancella
# Parola: essi
# cerca
# Parola: morti
# inserisci
# Parola: neppur
# cancella
# Parola: di
# cancella
# Parola: quelli,
# cancella
# Parola: l'Illustrissimo
# cancella
# Parola: ed
# ...
# Parola: bicchiere,
# cerca
# Parola: con
# cancella
# Parola: la
# inserisci
# Parola: mano
# cancella
# Parola: non
# inserisci
# Parola: ben
# inserisci
# Parola: ferma,
# cerca
# Parola: e
# cancella
# Parola: votandolo
# cerca
# Parola: poi
# cancella
# Parola: in
# cerca
# Parola: fretta,
# inserisci
# Parola: come
# cerca
# Parola: se
# cerca
# Parola: fosse
# cancella
# Parola: una
# cerca
# Parola: medicina.
# cancella
# Parola: -
# inserisci
# Parola: Vuol
# inserisci
# Parola: dunque
# cerca
# Parola: ch'io
# cancella
# Parola: sia
# inserisci
# Parola: costretta
# cancella
# Parola: di
# inserisci
# Parola: domandar
# inserisci
# Parola: qua
# inserisci
# Parola: e
# cerca
# Parola: l?
# inserisci
# Parola: cosa
# inserisci
# Parola: sia
# cancella
# Parola: accaduto
# cerca
# Parola: al
# cerca
# Parola: mio
# cancella
# Parola: padrone?
# cancella
# Parola: -
# cancella
# Parola: disse
# cerca
# Parola: Perpetua,
# inserisci
# Parola: ritta
# inserisci
# Parola: dinanzi
# cancella
# Parola: a
# inserisci
# Parola: lui,
# inserisci
# Parola: con
# cancella
# Parola: le
# cancella
# Parola: mani
# inserisci
# Parola: arrovesciate
# inserisci
# Parola: sui
# cancella
# Parola: fianchi,
# cancella
# Parola: e
# inserisci
# Parola: le
# inserisci
# Parola: gomita
# cerca
# Parola: appuntate
# cancella
# Parola: davanti,
# cancella
# Parola: guardandolo
# cerca
# Parola: fisso,
# cerca
# Parola: quasi
# cerca
# Parola: volesse
# inserisci
# Parola: succhiargli
# inserisci
# Parola: dagli
# cancella
# Parola: occhi
# cerca
# Parola: il
# cerca
# Parola: segreto.
# cancella
# Parola: -
# cerca
# Parola: Per
# cancella
# Parola: amor
# cerca
# Parola: del
# cancella
# Parola: cielo!
# cancella
# Parola: non
# cancella
# Parola: fate
# inserisci
# Parola: pettegolezzi,
# inserisci
# Parola: non
# inserisci
# Parola: fate
# cancella
# Parola: schiamazzi:
# cerca
# Parola: ne
# inserisci
# Parola: va...
# cancella
# Parola: ne
# inserisci
# Parola: va
# cerca
# Parola: la
# cerca
# Parola: vita!
# cerca
# Parola: -
# inserisci
# Parola: La
# cancella
# Parola: vita!
# inserisci
# Parola: -
# cancella
# Parola: La
# inserisci
# Parola: vita.
# cerca
# Parola: -
# inserisci
# Parola: Lei
# inserisci
# Parola: sa
# cerca
# Parola: bene
# cerca
# Parola: che,
# cerca
# Parola: ogni
# cerca
# Parola: volta
# cerca
# Parola: che
# inserisci
# Parola: m'ha
# cerca
# Parola: detto
# inserisci
# Parola: qualche
# cancella
# Parola: cosa
# cerca
# Parola: sinceramente,
# cancella
# Parola: in
# cerca
# Parola: confidenza,
# cerca
# Parola: io
# cancella
# Parola: non
# inserisci
# Parola: ho
# inserisci
# Parola: mai...
# cancella
# Parola: -
# cerca
# Parola: Brava!
# inserisci
# Parola: come
# cancella
# Parola: quando...
# cancella
# Parola: Perpetua
# cancella
# Parola: s'avvide
# cancella
# Parola: d'aver
# cerca
# Parola: toccato
# inserisci
# Parola: un
# cerca
# Parola: tasto
# cancella
# Parola: falso;
# cancella
# Parola: onde,
# cerca
# Parola: cambiando
# inserisci
# Parola: subito
# cerca
# Parola: il
# inserisci
# Parola: tono,
# inserisci
# Parola: -
# cerca
# Parola: signor
# cancella
# Parola: padrone,
# cancella
# Parola: -
# inserisci
# Parola: disse,
# inserisci
# Parola: con
# cancella
# Parola: voce
# cerca
# Parola: commossa
# inserisci
# Parola: e
# inserisci
# Parola: da
# inserisci
# Parola: commovere,
# cerca
# Parola: -
# cancella
# Parola: io
# inserisci
# Parola: le
# cancella
# Parola: sono
# inserisci
# Parola: sempre
# inserisci
# Parola: stata
# inserisci
# Parola: affezionata;
# cancella
# Parola: e,
# inserisci
# Parola: se
# inserisci
# Parola: ora
# cerca
# Parola: voglio
# cancella
# Parola: sapere,
# cerca
# Parola: ?
# inserisci
# Parola: per
# cancella
# Parola: premura,
# cancella
# Parola: perch?
# inserisci
# Parola: vorrei
# cerca
# Parola: poterla
# cerca
# Parola: soccorrere,
# cerca
# Parola: darle
# cerca
# Parola: un
# cerca
# Parola: buon
# cancella
# Parola: parere,
# cerca
# Parola: sollevarle
# cerca
# Parola: l'animo...
# inserisci
# Parola: Il
# inserisci
# Parola: fatto
# cerca
# Parola: sta
# inserisci
# Parola: che
# cancella
# Parola: don
# inserisci
# Parola: Abbondio
# cancella
# Parola: aveva
# inserisci
# Parola: forse
# cerca
# Parola: tanta
# cancella
# Parola: voglia
# cancella
# Parola: di
# cancella
# Parola: scaricarsi
# inserisci
# Parola: del
# inserisci
# Parola: suo
# cancella
# Parola: doloroso
# inserisci
# Parola: segreto,
# cerca
# Parola: quanta
# inserisci
# Parola: ne
# cerca
# Parola: avesse
# inserisci
# Parola: Perpetua
# cerca
# Parola: di
# inserisci
# Parola: conoscerlo;
# cancella
# Parola: onde,
# cerca
# Parola: dopo
# cancella
# Parola: aver
# cancella
# Parola: respinti
# inserisci
# Parola: sempre
# cerca
# Parola: pi?
# cancella
# Parola: debolmente
# cerca
# Parola: i
# cancella
# Parola: nuovi
# cancella
# Parola: e
# cancella
# Parola: pi?
# inserisci
# Parola: incalzanti
# cancella
# Parola: assalti
# inserisci
# Parola: di
# cancella
# Parola: lei,
# inserisci
# Parola: dopo
# inserisci
# Parola: averle
# cancella
# Parola: fatto
# inserisci
# Parola: pi?
# inserisci
# Parola: d'una
# cerca
# Parola: volta
# cerca
# Parola: giurare
# cerca
# Parola: che
# inserisci
# Parola: non
# cerca
# Parola: fiaterebbe,
# cancella
# Parola: finalmente,
# cerca
# Parola: con
# inserisci
# Parola: molte
# inserisci
# Parola: sospensioni,
# cancella
# Parola: con
# cancella
# Parola: molti
# inserisci
# Parola: ohim?,
# cancella
# Parola: le
# cancella
# Parola: raccont?
# inserisci
# Parola: il
# cerca
# Parola: miserabile
# cancella
# Parola: caso.
# cancella
# Parola: Quando
# cancella
# Parola: si
# cancella
# Parola: venne
# inserisci
# Parola: al
# cerca
# Parola: nome
# inserisci
# Parola: terribile
# cancella
# Parola: del
# inserisci
# Parola: mandante,
# cancella
# Parola: bisogn?
# cerca
# Parola: che
# cancella
# Parola: Perpetua
# cerca
# Parola: proferisse
# inserisci
# Parola: un
# cerca
# Parola: nuovo
# cancella
# Parola: e
# cancella
# Parola: pi?
# cancella
# Parola: solenne
# cancella
# Parola: giuramento;
# cerca
# Parola: e
# inserisci
# Parola: don
# inserisci
# Parola: Abbondio,
# inserisci
# Parola: pronunziato
# cancella
# Parola: quel
# cerca
# Parola: nome,
# inserisci
# Parola: si
# inserisci
# Parola: rovesci?
# inserisci
# Parola: sulla
# cerca
# Parola: spalliera
# inserisci
# Parola: della
# cancella
# Parola: seggiola,
# cancella
# Parola: con
# cancella
# Parola: un
# inserisci
# Parola: gran
# cerca
# Parola: sospiro,
# cerca
# Parola: alzando
# inserisci
# Parola: le
# cerca
# Parola: mani,
# inserisci
# Parola: in
# inserisci
# Parola: atto
# cerca
# Parola: insieme
# inserisci
# Parola: di
# cerca
# Parola: comando
# cancella
# Parola: e
# cerca
# Parola: di
# inserisci
# Parola: supplica,
# cerca
# Parola: e
# cancella
# Parola: dicendo:
# inserisci
# Parola: -
# inserisci
# Parola: per
# inserisci
# Parola: amor
# inserisci
# Parola: del
# inserisci
# Parola: cielo!
# inserisci
# Parola: -
# inserisci
# Parola: Delle
# cancella
# Parola: sue!
# cerca
# Parola: -
# cancella
# Parola: esclam?
# cerca
# Parola: Perpetua.
# cancella
# Parola: -
# cerca
# Parola: Oh
# cerca
# Parola: che
# cerca
# Parola: birbone!
# cancella
# Parola: oh
# inserisci
# Parola: che
# inserisci
# Parola: soverchiatore!
# cancella
# Parola: oh
# inserisci
# Parola: che
# cancella
# Parola: uomo
# cancella
# Parola: senza
# inserisci
# Parola: timor
# inserisci
# Parola: di
# cancella
# Parola: Dio!
# cancella
# Parola: -
# inserisci
# Parola: Volete
# cerca
# Parola: tacere?
# cancella
# Parola: o
# inserisci
# Parola: volete
# cancella
# Parola: rovinarmi
# inserisci
# Parola: del
# inserisci
# Parola: tutto?
# inserisci
# Parola: -
# cerca
# Parola: Oh!
# cerca
# Parola: siam
# cancella
# Parola: qui
# cancella
# Parola: soli
# inserisci
# Parola: che
# cerca
# Parola: nessun
# cerca
# Parola: ci
# cerca
# Parola: sente.
# cerca
# Parola: Ma
# cancella
# Parola: come
# cerca
# Parola: far?,
# cancella
# Parola: povero
# cancella
# Parola: signor
# cerca
# Parola: padrone?
# cerca
# Parola: -
# cancella
# Parola: Oh
# cerca
# Parola: vedete,
# inserisci
# Parola: -
# cancella
# Parola: disse
# inserisci
# Parola: don
# inserisci
# Parola: Abbondio,
# cancella
# Parola: con
# cerca
# Parola: voce
# cerca
# Parola: stizzosa:
# cancella
# Parola: -
# cerca
# Parola: vedete
# cancella
# Parola: che
# inserisci
# Parola: bei
# cancella
# Parola: pareri
# inserisci
# Parola: mi
# cerca
# Parola: sa
# cerca
# Parola: dar
# cancella
# Parola: costei!
# cancella
# Parola: Viene
# cancella
# Parola: a
# inserisci
# Parola: domandarmi
# cancella
# Parola: come
# cerca
# Parola: far?,
# cerca
# Parola: come
# cerca
# Parola: far?;
# cerca
# Parola: quasi
# cerca
# Parola: fosse
# cerca
# Parola: lei
# inserisci
# Parola: nell'impiccio,
# cerca
# Parola: e
# inserisci
# Parola: toccasse
# inserisci
# Parola: a
# cerca
# Parola: me
# cancella
# Parola: di
# inserisci
# Parola: levarnela.
# cerca
# Parola: -
# cerca
# Parola: Ma!
# cerca
# Parola: io
# cancella
# Parola: l'avrei
# cerca
# Parola: bene
# inserisci
# Parola: il
# cancella
# Parola: mio
# cancella
# Parola: povero
# cancella
# Parola: parere
# inserisci
# Parola: da
# cerca
# Parola: darle;
# inserisci
# Parola: ma
# cancella
# Parola: poi...
# cerca
# Parola: -
# inserisci
# Parola: Ma
# cerca
# Parola: poi,
# inserisci
# Parola: sentiamo.
# inserisci
# Parola: -
# cancella
# Parola: Il
# inserisci
# Parola: mio
# inserisci
# Parola: parere
# inserisci
# Parola: sarebbe
# cerca
# Parola: che,
# cancella
# Parola: siccome
# cancella
# Parola: tutti
# cancella
# Parola: dicono
# cerca
# Parola: che
# cerca
# Parola: il
# cancella
# Parola: nostro
# cerca
# Parola: arcivescovo
# cancella
# Parola: ?
# cerca
# Parola: un
# cerca
# Parola: sant'uomo,
# cancella
# Parola: e
# inserisci
# Parola: un
# cancella
# Parola: uomo
# cancella
# Parola: di
# cerca
# Parola: polso,
# cerca
# Parola: e
# cerca
# Parola: che
# inserisci
# Parola: non
# cancella
# Parola: ha
# cancella
# Parola: paura
# cerca
# Parola: di
# cancella
# Parola: nessuno,
# cerca
# Parola: e,
# inserisci
# Parola: quando
# inserisci
# Parola: pu?
# inserisci
# Parola: fare
# cancella
# Parola: star
# cancella
# Parola: a
# inserisci
# Parola: dovere
# cancella
# Parola: un
# inserisci
# Parola: di
# cerca
# Parola: questi
# cancella
# Parola: prepotenti,
# inserisci
# Parola: per
# cancella
# Parola: sostenere
# inserisci
# Parola: un
# inserisci
# Parola: curato,
# inserisci
# Parola: ci
# cerca
# Parola: gongola;
# inserisci
# Parola: io
# cerca
# Parola: direi,
# cancella
# Parola: e
# cerca
# Parola: dico
# inserisci
# Parola: che
# inserisci
# Parola: lei
# inserisci
# Parola: gli
# inserisci
# Parola: scrivesse
# inserisci
# Parola: una
# inserisci
# Parola: bella
# cerca
# Parola: lettera,
# cancella
# Parola: per
# cancella
# Parola: informarlo
# cancella
# Parola: come
# cancella
# Parola: qualmente...
# cerca
# Parola: -
# cerca
# Parola: Volete
# cerca
# Parola: tacere?
# inserisci
# Parola: volete
# inserisci
# Parola: tacere?
# cancella
# Parola: Son
# cancella
# Parola: pareri
# cancella
# Parola: codesti
# cancella
# Parola: da
# cerca
# Parola: dare
# cerca
# Parola: a
# inserisci
# Parola: un
# cancella
# Parola: pover'uomo?
# cancella
# Parola: Quando
# cancella
# Parola: mi
# cancella
# Parola: fosse
# cerca
# Parola: toccata
# inserisci
# Parola: una
# cancella
# Parola: schioppettata
# inserisci
# Parola: nella
# inserisci
# Parola: schiena,
# cerca
# Parola: Dio
# inserisci
# Parola: liberi!
# cancella
# Parola: l'arcivescovo
# cerca
# Parola: me
# cerca
# Parola: la
# cerca
# Parola: leverebbe?
# cerca
# Parola: -
# cerca
# Parola: Eh!
# inserisci
# Parola: le
# cerca
# Parola: schioppettate
# cancella
# Parola: non
# inserisci
# Parola: si
# cerca
# Parola: d?nno
# cancella
# Parola: via
# cerca
# Parola: come
# cerca
# Parola: confetti:
# cerca
# Parola: e
# cancella
# Parola: guai
# cancella
# Parola: se
# inserisci
# Parola: questi
# inserisci
# Parola: cani
# cerca
# Parola: dovessero
# cerca
# Parola: mordere
# inserisci
# Parola: tutte
# inserisci
# Parola: le
# cerca
# Parola: volte
# cancella
# Parola: che
# cerca
# Parola: abbaiano!
# inserisci
# Parola: E
# cancella
# Parola: io
# cerca
# Parola: ho
# cerca
# Parola: sempre
# cancella
# Parola: veduto
# cerca
# Parola: che
# inserisci
# Parola: a
# cerca
# Parola: chi
# inserisci
# Parola: sa
# cerca
# Parola: mostrare
# inserisci
# Parola: i
# cerca
# Parola: denti,
# cancella
# Parola: e
# inserisci
# Parola: farsi
# cancella
# Parola: stimare,
# cerca
# Parola: gli
# cerca
# Parola: si
# cerca
# Parola: porta
# cerca
# Parola: rispetto;
# cancella
# Parola: e,
# cancella
# Parola: appunto
# inserisci
# Parola: perch?
# inserisci
# Parola: lei
# cancella
# Parola: non
# cerca
# Parola: vuol
# cerca
# Parola: mai
# cancella
# Parola: dir
# cerca
# Parola: la
# inserisci
# Parola: sua
# cancella
# Parola: ragione,
# cerca
# Parola: siam
# cancella
# Parola: ridotti
# cancella
# Parola: a
# cancella
# Parola: segno
# cancella
# Parola: che
# cancella
# Parola: tutti
# inserisci
# Parola: vengono,
# cancella
# Parola: con
# inserisci
# Parola: licenza,
# inserisci
# Parola: a...
# inserisci
# Parola: -
# inserisci
# Parola: Volete
# inserisci
# Parola: tacere?
# cerca
# Parola: -
# cancella
# Parola: Io
# cancella
# Parola: taccio
# inserisci
# Parola: subito;
# cancella
# Parola: ma
# inserisci
# Parola: ?
# cancella
# Parola: per?
# cerca
# Parola: certo
# cerca
# Parola: che,
# cerca
# Parola: quando
# cancella
# Parola: il
# cerca
# Parola: mondo
# inserisci
# Parola: s'accorge
# inserisci
# Parola: che
# inserisci
# Parola: uno,
# cerca
# Parola: sempre,
# cancella
# Parola: in
# cerca
# Parola: ogni
# cerca
# Parola: incontro,
# inserisci
# Parola: ?
# cerca
# Parola: pronto
# cerca
# Parola: a
# cerca
# Parola: calar
# cerca
# Parola: le...
# inserisci
# Parola: -
# cancella
# Parola: Volete
# cancella
# Parola: tacere?
# inserisci
# Parola: ?
# inserisci
# Parola: tempo
# cerca
# Parola: ora
# inserisci
# Parola: di
# cancella
# Parola: dir
# inserisci
# Parola: codeste
# cancella
# Parola: baggianate?
# cerca
# Parola: -
# cancella
# Parola: Basta:
# cancella
# Parola: ci
# cerca
# Parola: penser?
# cancella
# Parola: questa
# inserisci
# Parola: notte;
# cancella
# Parola: ma
# cancella
# Parola: intanto
# cancella
# Parola: non
# inserisci
# Parola: cominci
# inserisci
# Parola: a
# cerca
# Parola: farsi
# cancella
# Parola: male
# inserisci
# Parola: da
# cancella
# Parola: s?,
# cerca
# Parola: a
# inserisci
# Parola: rovinarsi
# cancella
# Parola: la
# cerca
# Parola: salute;
# cancella
# Parola: mangi
# inserisci
# Parola: un
# cerca
# Parola: boccone.
# inserisci
# Parola: -
# inserisci
# Parola: Ci
# inserisci
# Parola: penser?
# cerca
# Parola: io,
# inserisci
# Parola: -
# cancella
# Parola: rispose,
# cerca
# Parola: brontolando,
# inserisci
# Parola: don
# cancella
# Parola: Abbondio:
# cerca
# Parola: -
# cancella
# Parola: sicuro;
# cerca
# Parola: io
# cancella
# Parola: ci
# cerca
# Parola: penser?,
# cancella
# Parola: io
# inserisci
# Parola: ci
# cancella
# Parola: ho
# cancella
# Parola: da
# cancella
# Parola: pensare
# cancella
# Parola: -
# inserisci
# Parola: E
# inserisci
# Parola: s'alz?,
# inserisci
# Parola: continuando:
# inserisci
# Parola: -
# cancella
# Parola: non
# inserisci
# Parola: voglio
# cancella
# Parola: prender
# inserisci
# Parola: niente;
# cerca
# Parola: niente:
# cerca
# Parola: ho
# cancella
# Parola: altra
# cancella
# Parola: voglia:
# cancella
# Parola: lo
# inserisci
# Parola: so
# cancella
# Parola: anch'io
# inserisci
# Parola: che
# inserisci
# Parola: tocca
# inserisci
# Parola: a
# inserisci
# Parola: pensarci
# cancella
# Parola: a
# cancella
# Parola: me.
# cancella
# Parola: Ma!
# cerca
# Parola: la
# cancella
# Parola: doveva
# inserisci
# Parola: accader
# cerca
# Parola: per
# cancella
# Parola: l'appunto
# inserisci
# Parola: a
# cancella
# Parola: me.
# inserisci
# Parola: -
# inserisci
# Parola: Mandi
# inserisci
# Parola: almen
# cancella
# Parola: gi?
# cerca
# Parola: quest'altro
# inserisci
# Parola: gocciolo,
# cancella
# Parola: -
# cancella
# Parola: disse
# cancella
# Parola: Perpetua,
# cerca
# Parola: mescendo.
# cancella
# Parola: -
# inserisci
# Parola: Lei
# cerca
# Parola: sa
# inserisci
# Parola: che
# cancella
# Parola: questo
# inserisci
# Parola: le
# cerca
# Parola: rimette
# cancella
# Parola: sempre
# cerca
# Parola: lo
# cerca
# Parola: stomaco.
# inserisci
# Parola: -
# cancella
# Parola: Eh!
# cerca
# Parola: ci
# cancella
# Parola: vuol
# cerca
# Parola: altro,
# inserisci
# Parola: ci
# cancella
# Parola: vuol
# cerca
# Parola: altro,
# cancella
# Parola: ci
# cancella
# Parola: vuol
# cancella
# Parola: altro.
# inserisci
# Parola: Cos?
# cerca
# Parola: dicendo
# cancella
# Parola: prese
# cancella
# Parola: il
# cerca
# Parola: lume,
# inserisci
# Parola: e,
# cancella
# Parola: brontolando
# cerca
# Parola: sempre:
# cerca
# Parola: -
# cerca
# Parola: una
# cancella
# Parola: piccola
# cancella
# Parola: bagattella!
# cancella
# Parola: a
# inserisci
# Parola: un
# cerca
# Parola: galantuomo
# cerca
# Parola: par
# cancella
# Parola: mio!
# inserisci
# Parola: e
# inserisci
# Parola: domani
# cancella
# Parola: com'andr??
# inserisci
# Parola: -
# cerca
# Parola: e
# cancella
# Parola: altre
# inserisci
# Parola: simili
# cancella
# Parola: lamentazioni,
# inserisci
# Parola: s'avvi?
# cerca
# Parola: per
# cerca
# Parola: salire
# cancella
# Parola: in
# cerca
# Parola: camera.
# cancella
# Parola: Giunto
# cerca
# Parola: su
# cerca
# Parola: la
# inserisci
# Parola: soglia,
# cerca
# Parola: si
# cerca
# Parola: volt?
# inserisci
# Parola: indietro
# cancella
# Parola: verso
# cerca
# Parola: Perpetua,
# cerca
# Parola: mise
# cancella
# Parola: il
# cerca
# Parola: dito
# inserisci
# Parola: sulla
# cancella
# Parola: bocca,
# cerca
# Parola: disse,
# cancella
# Parola: con
# inserisci
# Parola: tono
# cancella
# Parola: lento
# cerca
# Parola: e
# cerca
# Parola: solenne:
# inserisci
# Parola: -
# inserisci
# Parola: per
# cancella
# Parola: amor
# cancella
# Parola: del
# cancella
# Parola: cielo!
# cerca
# Parola: -,
# cancella
# Parola: e
# cerca
# Parola: disparve.
# inserisci
# tempototale =  2.3328750133514404 secondi
# CAPITOLO 1627, 13 -... - 1612. 1600, 1618, Abbondio ? 22 A ? Aveva Affrett? Abbondio, Aperto Avevano Brava! io Don Citt? Capitan Cameriero Ci Cos? Conte Dio anch'io Mandi E altre a altro. continuando: com'andr?? con dito disparve. doveva prender me. lo la l'appunto lamentazioni, lume, non mio! s'alz?, quest'altro questo stomaco. sa solenne: tocca volt?
