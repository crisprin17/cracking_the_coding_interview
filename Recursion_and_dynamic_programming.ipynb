# %% [markdown]
# # Exercise recursion
# Write a recursive function for generating all permutations of an input string. Return them as a set.

# %%
starting_string = 'Fin'

# %%
def get_permutations_recursively(string):
    # Base case
    if len(string) <= 1:
        return set([string])

    all_chars_except_last = string[1:]
    last_char = string[0]
    
    # Put the last char in all possible positions for each of
    # the above permutations
    permutations = set()
    
    print('last_char', last_char, 'rest of the string', all_chars_except_last)
    
    # Recursive call: get all possible permutations for all chars except last
    permutations_of_all_chars_except_last = get_permutations_recursively(all_chars_except_last)
    
    print(permutations_of_all_chars_except_last)

    for permutation_of_all_chars_except_last in permutations_of_all_chars_except_last:
        for position in range(len(all_chars_except_last) + 1):
            permutation = (
                permutation_of_all_chars_except_last[:position]
                + last_char
                + permutation_of_all_chars_except_last[position:]
            )
            permutations.add(permutation)

    return permutations

# %%
get_permutations_recursively(starting_string)
# Out:
# last_char F rest of the string in
# last_char i rest of the string n
# {'n'}
# {'in', 'ni'}
# {'Fin', 'Fni', 'iFn', 'inF', 'nFi', 'niF'}

# %% [markdown]
# ### iteratively
# import math
#
# def get_permutation_iteratively(string):
#     permutations = set()
#
#
#     while len(permutations) <= math.factorial(len(string)):
#         for index, letter in enumerate(string):
#             first_letter = string[index]
#             rest_of_the_string = string[index + 1:]
#             for second_index, second_letter in enumerate(rest_of_the_string):
#                 permutation_word = rest_of_the_string[:second_index] + first_letter + rest_of_the_string[second_index + 1:]
#                 print(rest_of_the_string[:second_index] + first_letter + rest_of_the_string[second_index + 1:])
#                 permutations.add(permutation_word)

# %%
get_permutation_iteratively(starting_string)
# Out:
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# iF
# i
# Fn
# ...

# %% [markdown]
# # Cake stealing = the unbounded knapsack problem."
# ## How can we ensure we get the optimal value we can carry?
# Let's see if we can build up to the given weight capacity, one capacity at a time, using the max values from previous capacities. How can we do this?
#
# Can we write a function to handle all the capacities?
#
# 1. To start, we'll need a way to store and update all the max monetary values for each capacity.

# %%
cake_tuples = [(25, 160), (3, 90), (2, 15)]
max_bag_capacity = 20

# %%
cake_tuple_reweight = [x[1] / x[0] for x in cake_tuples]
#tuple(map(lambda x: x[1] / x[0], cake_tuples))

# %%
cake_tuple_reweight
# Out:
# [6.4, 30.0, 7.5]

# %%
def reweight_value_over_ratio(cake_tuples: list) -> list:
    
    cake_tuple_reweight = cake_tuple_reweight(key=lambda x: x[1] / x[0])
    cake_tuples = cake_tuples.sorted(key=lambda x: x[1], reverse=True)


def max_duffel_bag_value(cake_tuples: list, max_bag_capacity: int) -> int:
    
    
    max_monetary_value = 0
    capacity = 0
    
    how_much_more_space = 0 
    
    while (max_bag_capacity > capacity):
        
        for item in range(len(cake_tuples)):
            print('for item = ', cake_tuples[item])
            current_capacity, current_value = cake_tuples[item]
            how_much_more_space
            
            if :
            
            
            capacity += current_capacity
            max_monetary_value = current_capacity * current_value
        else:
            break

    print('capacity = ', capacity,
          'max monetary value = ', max_monetary_value)
            
    
    return max_monetary_value
# Out:
#   File "<ipython-input-52-c45d1fb85d2b>", line 22
#     if :
#        ^
# SyntaxError: invalid syntax

# %%
max_duffel_bag_value(cake_tuples, capacity)
# Out:
# for item =  (25, 160)
# for item =  (3, 90)
# capacity =  25 max monetary value =  4000
# 4000
